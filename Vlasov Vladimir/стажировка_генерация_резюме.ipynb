# %% [markdown]
# # Ключевые навыки из базы резюме

# %%
# !wget -O resume.csv "https://docs.google.com/spreadsheets/d/1G6LR3Q8q-4WyjdGCriHCQIu8fUucjmZZDExZGq7yzo8/export?format=csv&id=1G6LR3Q8q-4WyjdGCriHCQIu8fUucjmZZDExZGq7yzo8&gid=222293530" --content-disposition

# %%
# !wget -O hh_resume.csv "https://drive.usercontent.google.com/download?id=11KfhKTh43tNTrAQmbqijKcoqVQHxjseO&export=download&authuser=0&confirm=t&uuid=4b8864c6-a7bd-4a26-bed0-feed51659773&at=APZUnTX1Tt-Kh8JApj0LA9Q7kPNN:1692898040914"

# %%
import pandas as pd

# %%
resume = pd.read_csv("resume.csv")

# %%
resume.columns

# %%
df = pd.read_csv("hh_resume.csv")

# %%
df['Ищет работу на должность:'].value_counts()[:50]

# %%
resume = df[df['Ищет работу на должность:']=="data scientist"].sample(1)
resume.to_dict()

# %%
df.columns

# %%
def get_key_skills(text):
    try:
        text = text.split(
            "Ключевые навыки Теперь резюме открыто всему"
            " интернету — изменить можно в настройках видимости."
        )[1].split(
            " Возникли неполадки."
        )[0]
    except:
        text = ""
    return text

# %%
df['key_skills'] = df['Опыт (двойное нажатие для полной версии)'].apply(get_key_skills)

# %%
mask = [
    'Ищет работу на должность:',
    'key_skills'
]

# %%
notnull_mask = df['key_skills'].astype(bool)
ex = df[notnull_mask][mask].sample(20)

# %%
df['Ищет работу на должность:'].str.split(',').explode().str.split(" / ").explode().shape

# %%
professions = df[notnull_mask]['Ищет работу на должность:'].str.split(',').explode().str.split(" / ").explode().str.strip().value_counts().to_dict()

# %%
df[notnull_mask]['Ищет работу на должность:'].str.split(',').explode().str.split(" / ").explode().str.strip().unique().shape

# %%
python_mask = df["Ищет работу на должность:"].str.contains("python")
scientist_mask = df["Ищет работу на должность:"].str.contains("scientist")

# %%
scientist_skills = df[notnull_mask][scientist_mask]['key_skills'].tolist()

# %%
print("\n".join(scientist_skills))

# %% [markdown]
# ### Вот 50 наиболее часто упоминаемых навыков в предоставленном тексте:
#
# 1. Python
# 2. SQL
# 3. Анализ данных
# 4. Machine learning
# 5. Data Mining
# 6. Статистический анализ
# 7. Аналитические исследования
# 8. Математическая статистика
# 9. Git
# 10. Математическое моделирование
# 11. Linux
# 12. Pandas
# 13. NumPy
# 14. MS Excel
# 15. Написание научных статей
# 16. Математический анализ
# 17. Базы данных
# 18. Sklearn
# 19. MS Office
# 20. Английский язык
# 21. Data Analysis
# 22. Разработка ПО
# 23. Keras
# 24. TensorFlow
# 25. Работа с большим объемом информации
# 26. Аналитическое мышление
# 27. Статистика
# 28. Навыки презентации
# 29. Big Data
# 30. MS SQL Server
# 31. Организаторские навыки
# 32. Работа в команде
# 33. Деловое общение
# 34. Ведение переговоров
# 35. Проведение презентаций
# 36. Анализ бизнес процессов
# 37. Деловая переписка
# 38. Управление проектами
# 39. MATLAB
# 40. Oracle
# 41. Сбор и анализ информации
# 42. Пользователь ПК
# 43. Грамотная речь
# 44. Разработка технических заданий
# 45. MS Visual Studio
# 46. Моделирование
# 47. Стрессоустойчивость
# 48. Анализ инвестиционных проектов
# 49. Управление персоналом
# 50. Визуализация данных

# %%
python_skills = df[notnull_mask][python_mask]['key_skills'].tolist()
print("\n".join(python_skills))

# %% [markdown]
# ### Вот 50 наиболее часто упоминаемых навыков в последнем предоставленном тексте:
#
# 1. Python
# 2. Git
# 3. Linux
# 4. SQL
# 5. Django Framework
# 6. JavaScript
# 7. MySQL
# 8. HTML
# 9. CSS
# 10. jQuery
# 11. ООП
# 12. PostgreSQL
# 13. Администрирование серверов Linux
# 14. MS Visual Studio
# 15. Разработка ПО
# 16. C++
# 17. Node.js
# 18. MongoDB
# 19. MS SQL
# 20. Базы данных
# 21. Docker
# 22. PHP
# 23. Redis
# 24. Английский язык
# 25. Nginx
# 26. С#
# 27. Flask
# 28. REST
# 29. Работа в команде
# 30. API
# 31. Управление проектами
# 32. Java
# 33. Веб-программирование
# 34. Ruby
# 35. Android SDK
# 36. AWS
# 37. RabbitMQ
# 38. React
# 39. SDL
# 40. Apache HTTP Server
# 41. Golang
# 42. TensorFlow
# 43. Machine Learning
# 44. MS Office
# 45. GitLab
# 46. NumPy
# 47. XML
# 48. Kubernetes
# 49. OpenCV
# 50. Vue.js

# %%
python_key = [key for key in professions.keys() if "python" in key]

# %%
 python_key

# %% [markdown]
# # Создание базы знаний

# %%
# @title Установка пакетов
from IPython.display import clear_output

# !pip install --upgrade tiktoken
# !pip install langchain openai
# !pip install faiss-cpu

clear_output()

import getpass
import openai
import os
def get_key_ОpenAI():
  openai.api_key = getpass.getpass(prompt='Введите секретный ключ для сервиса chatGPT: ')
  os.environ["OPENAI_API_KEY"] = openai.api_key

get_key_ОpenAI()

# Для работы с Google Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Введите секретный ключ для сервиса chatGPT: ··········
# Mounted at /content/drive

# %%
#@title Импорт библиотек и Сервисные функции
import gdown
from IPython.display import clear_output
from langchain.llms import OpenAI
from langchain.docstore.document import Document
import requests
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.text_splitter import CharacterTextSplitter
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.prompts import PromptTemplate
import pathlib
import subprocess
import tempfile

import time
import os
import openai
import tiktoken
import re
import os
import json
from tqdm.auto import tqdm
import getpass
from tqdm.auto import tqdm

# ----------------------------------
MODEL_TURBO_16K = "gpt-3.5-turbo-16k"
MODEL_TURBO_0613 = "gpt-3.5-turbo-0613"
MODEL_GPT4 = "gpt-4-0613"
# ----------------------------------

clear_output()

class WorkerОpenAI():
  def __init__(self, \
               system_promt = " ", \
               system_promt_lector = " ", \
               mod = MODEL_TURBO_16K, \
               content_topics = None, \
               save_project = '/content/'):
    self.model = mod
    self.save_project  = save_project

    if content_topics:
      self.content_topics = self.load_txt_file(content_topics)

    # системные настройки
    self.system_promt = system_promt
    self.speaker_system_promt = system_promt_lector


  def load_document_text(self, url: str) -> str:
      # функция для загрузки документа по ссылке из гугл док
      match_ = re.search('/document/d/([a-zA-Z0-9-_]+)', url)
      if match_ is None:
          raise ValueError('Invalid Google Docs URL')
      doc_id = match_.group(1)
      response = requests.get(
          f'https://docs.google.com/document/d/{doc_id}/export?format=txt')
      response.raise_for_status()
      text = response.text
      return text


  def load_txt_file(self, file_path):
      with open(file_path, 'r') as file_:
          text = file_.read()
      return text

  # пример подсчета токенов
  def num_tokens_from_messages(self, messages):
      """Returns the number of tokens used by a list of messages."""
      try:
          encoding = tiktoken.encoding_for_model(self.model)
      except KeyError:
          encoding = tiktoken.get_encoding("cl100k_base")
      # if self.model == "gpt-3.5-turbo-0301":  # note: future models may deviate from this
      if self.model in ["gpt-3.5-turbo-0613", "gpt-3.5-turbo-16k", "gpt-4-0613"]:
         # note: future models may deviate from this
          num_tokens = 0
          for message in messages:
              num_tokens += 4  # every message follows <im_start>{role/name}\n{content}<im_end>\n
              for key, value in message.items():
                  num_tokens += len(encoding.encode(value))
                  if key == "name":  # if there's a name, the role is omitted
                      num_tokens += -1  # role is always required and always 1 token
          num_tokens += 2  # every reply is primed with <im_start>assistant
          return num_tokens
      else:
          raise NotImplementedError(f"""num_tokens_from_messages() is not presently implemented for model {self.model}.
  See https://github.com/openai/openai-python/blob/main/chatml.md for information on how messages are converted to tokens.""")


  def create_embedding_faiss_db(self, doc_txt_dir="/content/", \
                                faiss_db_dir ="/content/", \
                                start_idx = 0, \
                                collection_name = " "):

    def num_tokens_from_string(string: str, encoding_name: str) -> int:
      """Returns the number of tokens in a text string."""
      encoding = tiktoken.get_encoding(encoding_name)
      num_tokens = len(encoding.encode(string))
      return num_tokens

    # Для Копирайтера
    # self.splitter = RecursiveCharacterTextSplitter(
    #     ['# ', '## ', '### ', "#### ", "##### "], chunk_size=1024, chunk_overlap=300)
    self.splitter = TokenTextSplitter(chunk_size=900, chunk_overlap=100)
    idx_file_folder = start_idx-1
    chunkID = idx_file_folder

    count_tokens = 0
    # проходимся по всем данным
    for _, file_ in enumerate(sorted(os.listdir(doc_txt_dir))):
        print("Загружается файл: ", file_)
        self.file_name = file_
        idx_file_folder +=1
        source_chunks = []
        # разбиваем на несколько частей с помощью метода split_text
        with open(doc_txt_dir + file_, "r") as f:
          for chunk in self.splitter.split_text(f.read()):
              chunkID += 1
              source_chunks.append(Document(page_content=chunk, \
                                  metadata={'source': file_,
                                            'chunkID': chunkID,
                                            "collection_name": collection_name,
                                            'idx_file_folder': idx_file_folder}))


        # Создание индексов документа и СОХРАНЕНИЕ
        # Если документ не пуст, то создать и сохранить базу индексов эмбеддингов отрезков документа
        if len(source_chunks) > 0:
            self.db = FAISS.from_documents(source_chunks, OpenAIEmbeddings())
            count_token = num_tokens_from_string(
                ' '.join([x.page_content for x in source_chunks]), "cl100k_base"
                )
            count_tokens += count_token
            print('Количество токенов в документе :', count_token)
            # print('ЦЕНА запроса:', 0.0004 * (count_token / 1000), ' $')

            self.db.save_local(
                os.path.join(
                    faiss_db_dir, collection_name,
                    f"{str(idx_file_folder)}_db_initial__{file_[:20]}"))

    print('\nЦЕНА запроса создания базы индексов:', 0.0004 * (count_tokens / 1000), ' $')

# ЗАПРС в ChatGPT
  def get_ChatCompletion(self, model,  # указываем модель
                         messages,     # словарь запроса
                         temp=0.1):    # температуру

      completion = openai.ChatCompletion.create(
        model= model,
        messages= messages,
        temperature= temp
        )

      print(
          f'{completion["usage"]["total_tokens"]} токенов использовано всего (вопрос-ответ).')
      # print('ЦЕНА запроса с ответом :', 0.0015*(completion["usage"]["total_tokens"]/1000), ' $')
      print('===========================================: \n')
      return completion.choices[0].message.content

# ЗАПРС на создание темы и подтемы по Материалам
  def get_search_materials_topics_subtopics(self, materials,
                                            model_topics = "gpt-3.5-turbo-16k"):

    messages = [
        {"role": "system", "content": f"{self.system_promt}"},
        {"role": "user",
         "content": f"""Проанализируй отрывок материала c семинара: {materials}.

Дай компактный, сжатый, обобщенный список тем и подтем.
Темы Необходимо оформить _#, а подтемы оформить ##_.
Используй только такой пример, ничего не добавляй лишнего.
Пример составления списка:
_#...
##_...
_#...
##_...
        """}
        ]

    # example token count from the function defined above
    print(f"{self.num_tokens_from_messages(messages=messages)} токенов использовано на вопрос \n")
    try:
      self.content_topics += self.get_ChatCompletion(model_topics, messages)
    except:
      print("Модель в настоящее время перегружена. Попробуйте позже.")


# ПОИСК ТЕМЫ и ПОДТЕМЫ
  def search_topics_subtopics(self, num_chunk = 10):
    self.content_topics = ''
    materials = ""
    # Выбираем блоки ПОДРЯД
    len_chunk = len(self.db.docstore._dict)
    if len_chunk < num_chunk + 1:
        for _, doc in self.db.docstore._dict.items():
            materials += f"{doc.page_content}\n"
        self.get_search_materials_topics_subtopics(materials)
    else:
        for ind, (key, doc) in enumerate(self.db.docstore._dict.items()):
          materials += f"{doc.page_content}\n"
          if (ind+1) % num_chunk == 0:
            self.get_search_materials_topics_subtopics(materials)
            materials = ""
    if materials != "":
        self.get_search_materials_topics_subtopics(materials)

    print('Собрали список тем и подтем: ')
    print(self.content_topics)

    with open(f'{self.save_project}{self.file_name[:20]}__темы_подтемы.txt', "w") as f:
      f.write(self.content_topics)


# ОБЪЕДИНЯЕМ схожие ТЕМЫ
  def get_merge_topics(self, model_topics = "gpt-3.5-turbo-16k"):

    messages = [
        {"role": "system", "content": f"{self.system_promt}"},
        {"role": "user",
         "content": f"""Проанализируй Темы и подтемы Семинара: {self.content_topics}.

Необходимо объединить похожие по смыслу темы или подтемы, записать компактно.
При необходимости перефразировать тему или подтему. Дай корректный список.
Темы оформи _#, а подтемы оформи ##_.
Используй только такой пример, ничего не добавляй лишнего.
Пример составления списка:
_#...
##_...
_#...
##_...
"""}
]
    # example token count from the function defined above
    print(f"{self.num_tokens_from_messages(messages=messages)} токенов использовано на вопрос \n")
    try:
      self.content_topics = self.get_ChatCompletion(model_topics, messages)
      print('Итоговый список тем и подтем: ')
      print(self.content_topics)
      with open(f'{self.save_project}{self.file_name[:20]}__темы_подтемы_ИТОГ.txt', "w") as f:
        f.write(self.content_topics)
    except:
      print("Модель в настоящее время перегружена. Попробуйте позже.")

# ОРГАНИЗУЕМ текст блоками
  def organize_text(self, topic, num_chunks, model_topics):

    # Выборка документов по схожести с подтемой
    docs = self.db.similarity_search(topic, k = num_chunks)
    message_content = '\n'.join(
        [doc.page_content + '\n' for i, doc in enumerate(docs)])

    messages = [
        {"role": "system", "content": f"{self.speaker_system_promt}"},
        {"role": "user", "content": f"""Вот отрывки Вашей лекции:\n{message_content}

Опираясь только на информацию с Лекции, указанной выше, расскажите подробнее по Теме: {topic}.
"""}
      ]

    # example token count from the function defined above
    print('\n ===========================================: ')
    print(f"{self.num_tokens_from_messages(messages=messages)} токенов использовано на вопрос \n")
    try:
      self.final_text += self.get_ChatCompletion(model_topics, messages)
    except:
      print("Модель в настоящее время перегружена. Попробуйте позже.")

# ОРГАНИЗУЕМ ИТОГОВЫЙ ТЕКСТ
  def organize_final_text(self, num_chunks = 10,
                          model_topics = "gpt-3.5-turbo-16k",
                          name = None,
                          db_path = None):
    if name:
      self.file_name = name

    if db_path:
      for curr_base in os.listdir(db_path):
          self.db = FAISS.load_local(
              os.path.join(db_path, curr_base), OpenAIEmbeddings())

    self.final_text = ""
    list_topics = self.content_topics.split('\n')
    # проходимся по списку тем и подтем
    for ind, topic in tqdm(enumerate(list_topics)):
        # тему просто записываем в итоговый текст
        if ("_#" in topic) and not("_#" in list_topics[ind+1]):
          self.final_text += f'\n{topic}\n'
        # подтему передаем в ChatGPT
        else:
          self.final_text += f'\n{topic}\n'
          self.organize_text(topic, num_chunks, model_topics)

    with open(
        f'{self.save_project}{self.file_name[:20]}__final_text.txt', "w") as f:
      f.write(self.final_text)
    print("\nСоздали финальный документ для Базы Знаний (final_text)")





clear_output()

# %% [markdown]
# ## Файлы

# %%
# ссылки на обработанные HR-документы
urls = [
    "https://docs.google.com/document/d/1j4coap4TKa3O2m5B-r5VDHCZ0T7JUlP1/edit",
    "https://docs.google.com/document/d/1y-NOtYjH1OYb-pF7KvPqIbUfNffqvW0m/edit?usp=sharing&ouid=102193262998923889820&rtpof=true&sd=true",
    "https://docs.google.com/document/d/1sBkBsR3Xt1Uepfts6Qol6gPd4dUyTaHm/edit",
    "https://docs.google.com/document/d/1rrodzeu-w_XrRSt4PmuNN6m8z5Lt4yWv/edit",
    "https://docs.google.com/document/d/1ER3E6Up7ek5X1KIC3q961l9dv4F_TGRV/edit",
    "https://docs.google.com/document/d/1Pmxnn3BBCgVLutdL4EV9fSrkVSpPaSdp/edit",
]

# %%
  def load_document_text(url: str) -> str:
      # функция для загрузки документа по ссылке из гугл док
      match_ = re.search('/document/d/([a-zA-Z0-9-_]+)', url)
      if match_ is None:
          raise ValueError('Invalid Google Docs URL')
      doc_id = match_.group(1)
      response = requests.get(
          f'https://docs.google.com/document/d/{doc_id}/export?format=txt')
      response.raise_for_status()
      text = response.text
      return text

# %%
resume_texts = "\n\n".join(map(load_document_text, urls))
with open(f'resume_recomendations.txt', "w") as f:
    f.write(resume_texts)

# %%
topic, *text = resume_texts.split("\r\n# ")[0].split('\r\n')

# %%
resume_texts
# Out:
# '\ufeff# Персональная информация\r\n# Контакты (можно объединить с персональной информацией) \r\n# Фото\r\n# Цель (Желаемая должность и специализация)\r\n# Краткое резюме (можно объединить с "опыт работы")\r\n# Опыт работы:\r\n   - Названия компаний и проектов  \r\n   - Периоды работы\r\n   - Должности\r\n   - Обязанности и достижения\r\n   - Ключевые результаты\r\n   - Использованные технологии и навыки\r\n   - Пример\r\n# Образование\r\n   - Учебные заведения\r\n   - Специальности\r\n   - Даты обучения\r\n   - Курсы, тренинги, сертификаты\r\n   - Пример\r\n# Навыки (Hard skills)\r\n   - Технические навыки\r\n   - Языки программирования\r\n   - Инструменты и технологии\r\n   - Пример\r\n# Дополнительно\r\n   - Хобби, интересы\r\n   - Готовность к командировкам\r\n   - Портфолио, GitHub\r\n   - Рекомендации\r\n   - Пример\r\n# Языки\r\n# О себе\r\n# Личные качества (Soft Skills)\r\n# Рекомендации по составлению резюме\r\n# Портфолио\r\n# LinkedIn\r\n# GitHub\r\n# Проверка\r\n        
# ...

# %%
def structure_text(resume_texts, splitter):
    docs = {}
    for topic_text in resume_texts.split(splitter):     # "\r\n# "
        topic, *text = topic_text.split("\n")
        text = "\n".join(text)
        topic = topic.strip()
        if docs.get(topic, False):
            docs[topic] += "\n" + text
            continue

        docs[topic] = "\n" + text
    return docs

# %%
topics = structure_text(resume_texts, "\r\n# ")

# %%
docs = {key:structure_text(topics[key],"\n## ") for key in topics.keys()}
# structure_text(topics["Навыки"],"\n## ")

# %%
docs.keys()
# Out:
# dict_keys(['\ufeff# Персональная информация', 'Контакты (можно объединить с персональной информацией)', 'Фото', 'Цель (Желаемая должность и специализация)', 'Краткое резюме (можно объединить с "опыт работы")', 'Опыт работы:', 'Образование', 'Навыки (Hard skills)', 'Дополнительно', 'Языки', 'О себе', 'Личные качества (Soft Skills)', 'Рекомендации по составлению резюме', 'Портфолио', 'LinkedIn', 'GitHub', 'Проверка', 'Оформление резюме', 'Сопроводительное письмо', 'Пустой текст', 'Опыт работы', 'Пример', 'Личные качества', 'Навыки', 'Контакты', 'Цель', 'Хобби', 'Персональная информация', 'Краткое резюме', 'Сопроводительное письмо.'])

# %%
docs["Личные качества"].keys()
# Out:
# dict_keys(['', 'Junior', 'Data Science'])

# %% [markdown]
# # Copywriter

# %%
#@title Создаем объект для работы Copywriter
# projects_dir = '/content/drive/MyDrive/Colab Notebooks/_Projects_ChatGPT/Нейро_Copywriter/УИИ/'
projects_dir = '/content/'

# Promt_copywriter = "https://docs.google.com/document/d/1Pdmys-RHFa7c_teMv8AJkgOfFhK0sHij285CycfKGvs/edit?usp=sharing"
# Promt_lector = "https://docs.google.com/document/d/1HYA19tp2BP08IL5ltHYjssEen70rIS-jy44E6hmt-Jo/edit?usp=sharing"


Promt_copywriter = """\
Ты профессиональный копирайтер. У тебя большой опыт работы с Бизнесом в разных сферах.

Ты профессионально составляешь и структурируешь тексты, умеешь выделять важные моменты в каждом тексте.

Твоя цель: Качественно структурировать текст на Русском языке и выделять основные Темы и Подтемы.
"""

Promt_lector = """\
Ты Лектор, Спикер на Семинаре. Ты профессионал своего дела.
Тебе предоставят отрывок Твоей Лекции и попросят раскрыть подробнее одну из тем Семинара.

Твоя цель: Опираясь только на Лекцию, подробно, развернуто рассказать по интересующей теме на русском языке.
Необходимо уложиться в 2000 слов.
"""


# если темы созданы
# topics_final = "/content/drive/MyDrive/Colab Notebooks/_Projects_ChatGPT/Нейро_Copywriter/УИИ/___.txt"
# # Создаем объект для дообучения chatGPT
curator = WorkerОpenAI(system_promt = Promt_copywriter, # системный промт
                       system_promt_lector = Promt_lector, # промт Лектора
                      #  content_topics = topics_final,
                       save_project = projects_dir)     # путь для сохранения готовых файлов

# Формируем базу по файлу txt
# путь к материалам
doc_txt_dir = "/content/Resume/"
db_initial = projects_dir

curator.create_embedding_faiss_db(doc_txt_dir = doc_txt_dir,   # путь к материалам
                                faiss_db_dir = db_initial,     # путь для сохранения исходной базы
                                start_idx = 0,                 # номер документа в базе
                                collection_name = 'HR_db_initial2')  # наименование коллекции

# %%
# Смотрим созданные чанки
print(f"Текст разбит на чанки. Всего: {len(curator.db.docstore._dict.values())} шт.\n")
curator.db.docstore._dict.values()
# Out:
# Текст разбит на чанки. Всего: 279 шт.
# ...

# %%
#@title Поиск темы и подтемы выборкой по 5 - 15 чанков

# Подаем в цикле и просим составить список тем и подтем.
curator.search_topics_subtopics(num_chunk = 15)
# Out:
# 6145 токенов использовано на вопрос
#
# 6690 токенов использовано всего (вопрос-ответ).
# ===========================================:
#
# 6060 токенов использовано на вопрос
#
# 6395 токенов использовано всего (вопрос-ответ).
# ===========================================:
#
# 6131 токенов использовано на вопрос
#
# 6440 токенов использовано всего (вопрос-ответ).
# ===========================================:
#
# 6211 токенов использовано на вопрос
#
# 7413 токенов использовано всего (вопрос-ответ).
# ===========================================:
#
# 6071 токенов использовано на вопрос
#
# 7769 токенов использовано всего (вопрос-ответ).
# ===========================================:
#
# 5858 токенов использовано на вопрос
#
# 6813 токенов использовано всего (вопрос-ответ).
# ===========================================:
#
# 5793 токенов использовано на вопрос
#
# 6442 токенов использовано всего (вопрос-ответ).
# ===========================================:
#
# ...

# %%
#@title Корректируем список тем и подтем (обобщаем, убираем дубли).
# Подаем сформированный Список тем и просим объединить похожие по смыслу темы или подтемы, записать компактно.
# При необходимости перефразировать тему или подтему.
curator.get_merge_topics()
# Out:
# 12266 токенов использовано на вопрос
#
# 12615 токенов использовано всего (вопрос-ответ).
# ===========================================:
#
# Итоговый список тем и подтем:
# # Составление резюме
#
# ## Обязанности
# - Простой путь к составлению обязанностей в резюме
# - Необходимость указывать конкретные действия на проекте
# - Примеры конкретных обязанностей для разных должностей
#
# ## Навыки
# - Ключевые достижения в резюме
# - Как формулировать достижения
# - Примеры измеримых достижений
# - Указание командных достижений
# - Рекомендации для новичков
#
# ## Технологии
# - Актуальность указания технологий
# - Необходимость добавления комментариев к технологиям
# - Рекомендации для фулстек-разработчиков
#
# ## Дополнительно
# - Рекомендации
# - Значение рекомендаций в резюме
#
# ## Рекомендации по составлению резюме
# - Чек-лист для составления резюме
# - Важность начала резюме
# - Порядок размещения информации в резюме
# - Количество страниц в резюме
# ...

# %%
add_topics = """
# Персональная информация
# Контакты (можно объединить с персональной информацией)
# Фото
# Цель (Желаемая должность и специализация)
# Краткое резюме (можно объединить с "опыт работы")
# Опыт работы:
# Опыт работы: Названия компаний и проектов
# Опыт работы: Периоды работы
# Опыт работы: Должности
# Опыт работы: Обязанности и достижения
# Опыт работы: Ключевые результаты
# Опыт работы: Использованные технологии и навыки
# Опыт работы: Пример
# Образование
# Образование: Специальности
# Образование: Учебные заведения
# Образование: Даты обучения
# Образование: Курсы, тренинги, сертификаты
# Образование: Пример
# Навыки (Hard skills)
# Навыки (Hard skills): Технические навыки
# Навыки (Hard skills): Языки программирования
# Навыки (Hard skills): Инструменты и технологии
# Навыки (Hard skills): Пример
# Дополнительно
# Дополнительно: Хобби, интересы
# Дополнительно: Готовность к командировкам
# Дополнительно: Портфолио, GitHub
# Дополнительно: Рекомендации
# Дополнительно: Пример
# Языки
# О себе
# Личные качества (Soft Skills)
# Рекомендации по составлению резюме
# Портфолио
# LinkedIn
# GitHub
# Проверка
# Проверка: Грамматика и ошибки
# Проверка: Соответствие требованиям
# Оформление резюме
# Оформление резюме: Структурированность
# Оформление резюме: Выделение разделов
# Сопроводительное письмо
"""

# %%
curator.content_topics += add_topics

# %%
curator.content_topics
# Out:
# '# Составление резюме\n\n## Обязанности\n- Простой путь к составлению обязанностей в резюме\n- Необходимость указывать конкретные действия на проекте\n- Примеры конкретных обязанностей для разных должностей\n\n## Навыки\n- Ключевые достижения в резюме\n- Как формулировать достижения\n- Примеры измеримых достижений\n- Указание командных достижений\n- Рекомендации для новичков\n\n## Технологии\n- Актуальность указания технологий\n- Необходимость добавления комментариев к технологиям\n- Рекомендации для фулстек-разработчиков\n\n## Дополнительно\n- Рекомендации\n- Значение рекомендаций в резюме\n\n## Рекомендации по составлению резюме\n- Чек-лист для составления резюме\n- Важность начала резюме\n- Порядок размещения информации в резюме\n- Количество страниц в резюме\n- Рекомендации по форматам файлов резюме\n# Персональная информация\n# Контакты (можно объединить с персональной информацией) \n# Фото\n# Цель (Желаемая должность и специализация)\n# Краткое резюме (можно объединить с "опыт 
# ...

# %%
Promt_lector = """\
Ты Лектор, опытный HR-ассистент. Ты профессионал своего дела.
Тебе предоставят отрывок документа по качественному, правильному составлению резюме\
 и попросят подробнее рассказать как грамотно составить определенный раздел резюме.

Твоя цель: Опираясь только на документы по качественному, правильному составлению резюме,\
 подробно, развернуто рассказать по интересующей теме на русском языке.
Необходимо уложиться в 2000 слов.
"""

# %%
curator.speaker_system_promt = Promt_lector

# %% [markdown]
# ## ОРГАНИЗУЕМ ИТОГОВЫЙ ТЕКСТ

# %% [markdown]
# Выборка блоков документов по схожести с подтемой. Передаем собранные отрывки с Лекции и просим рассказать подробнее, опираясь на Лекцию.

# %%
# запускаем сбору Итогового Текста
# name_file = 'Разбор нейро-сотрудников на chatGPT _ 21.08.2023'
# db_initial = '/content/drive/MyDrive/Colab Notebooks/_Projects_ChatGPT/Нейро_Copywriter/УИИ/УИИ_db_initial'

# curator.organize_final_text(name = name_file, db_path = db_initial)
curator.organize_final_text(num_chunks = 9)
# Out:
# 0it [00:00, ?it/s]
#  ===========================================:
# 3638 токенов использовано на вопрос
#
# 4844 токенов использовано всего (вопрос-ответ).
# ===========================================:
#
#
#  ===========================================:
# 2371 токенов использовано на вопрос
#
# 3708 токенов использовано всего (вопрос-ответ).
# ===========================================:
#
#
#  ===========================================:
# 3473 токенов использовано на вопрос
#
# 4368 токенов использовано всего (вопрос-ответ).
# ===========================================:
#
#
#  ===========================================:
# 3636 токенов использовано на вопрос
#
# 4658 токенов использовано всего (вопрос-ответ).
# ===========================================:
#
#
#  ===========================================:
# 3570 токенов использовано на вопрос
#
# 4212 токенов использовано всего (вопрос-ответ).
# ===========================================:
#
#
# ...

# %%
# сформирован итоговый текст
curator.final_text
# Out:
# '\n# Содержание:\nСодержание: Составление резюме для IT-специалиста\n\nВ современном мире поиск работы в IT-сфере становится все более конкурентным. Чтобы выделиться среди множества кандидатов, необходимо иметь качественное и информативное резюме. В данной лекции мы рассмотрим основные принципы составления резюме для IT-специалиста.\n\nПервым шагом при составлении резюме является выбор правильной структуры. Обычно резюме IT-специалиста состоит из следующих разделов:\n\n1. Контактная информация: в этом разделе указываются имя, фамилия, контактный номер телефона и электронная почта. Также можно добавить ссылки на профили в социальных сетях, таких как LinkedIn или GitHub.\n\n2. Цель: в этом разделе указывается, на какую вакансию вы претендуете и какие цели вы ставите перед собой в карьере.\n\n3. Образование: здесь указывается ваше образование, включая название учебного заведения, специальность и год окончания.\n\n4. Опыт работы: в этом разделе указывается ваш опыт работы, начиная с посл
# ...

# %% [markdown]
# # Эксперименты с markdown

# %%
# !pip install unstructured

# %%
# from unstructured.partition.md import partition_md
# from unstructured.chunking.title import chunk_by_title

# url = "all_resume.md"
# elements = partition_md(url)
# chunks = chunk_by_title(elements)

# for chunk in chunks:
#     print(chunk)
#     print("\n\n" + "-"*80)
#     input()

# %%
from langchain.document_loaders.markdown import UnstructuredMarkdownLoader
loader = UnstructuredMarkdownLoader(
    "all_resume2.md",
    mode="elements",
    strategy="fast",
)
docs = loader.load()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
# loader2 = UnstructuredMarkdownLoader(
#     "resume_recomendations.txt",
#     mode="elements",
#     # strategy="fast",
#     combine_under_n_chars=0,
#     new_after_n_chars=1000

# )
# docs3 = loader2.load()

# %%
from langchain.document_loaders import TextLoader

loader3 = TextLoader("all_resume2.md")
docs2 = loader3.load()

# %%
from langchain.text_splitter import CharacterTextSplitter, TokenTextSplitter

text_splitter = TokenTextSplitter(chunk_size=900, chunk_overlap=100)
split_docs = text_splitter.split_documents(docs2)

# %%
max([len(doc.page_content) for doc in docs]), max([len(doc.page_content) for doc in split_docs])
# max([len(doc.page_content) for doc in recursive_split_docs])
# Out:
# (1047, 1278)

# %%
len(docs), len(split_docs), len(docs2)
# Out:
# (1619, 279, 1)

# %%
filtred_docs = [doc for doc in docs if len(doc.page_content)>100]
len(filtred_docs)
# Out:
# 655

# %%
len(filtred_docs[0].page_content)
# Out:
# 206

# %%
split_docs[50].page_content
# Out:
# '�ли заниматься одним и тем же, но технически\nполучается, что намного выигрышнее выглядит второй человек, потому что\nон рассказал, чего достиг, а не просто перечисляет обязанности.\n\nЕсли кто-то подумает, а действительно ли второй кандидат такой молодец\n--- детали можно узнать на техническом собеседовании, до которого\nдоходят далеко не все.\\\nПодумайте, какие нововведения вы инициировали. Например: «Я внедрил\ncustomer development и мы начали зарабатывать больше денег». Это сразу\nувеличивает ваши шансы попасть на следующий этап.\n\n### **3. Определить компании, в которые собираетесь подаваться**\n\nЗдесь не обязательно фокусироваться на 2-3 компаниях. Достаточно хотя бы\nопределить профиль, например, аутсорс или продукт. И, соответственно,\nпланомерно отфильтровать свои навыки в соответствии с запросами\nкомпаний.\n\n*Я обычно выбираю 4 компании и относительно каждой из них создаю 4\nрезюме, в которых максимально фильтрую все то, что расписал на 4\nстран'

# %%
len(split_docs[50].page_content), len(split_docs)
# Out:
# (962, 257)

# %%
splitter = RecursiveCharacterTextSplitter(
        ['# ', '## ', '### ', "#### ", "##### ", "\n\n"], chunk_size=1024, chunk_overlap=100)
recursive_split_docs = splitter.split_documents(docs2)

# %%
len(split_docs)
# Out:
# 289

# %%
recursive_split_docs[55].page_content
# Out:
# '# Hobbies and Interests\n\nЕдва ли не самый последний раздел, на который обращают внимание\nрекрутеры, так как он не связан с работой. Тем не менее многие кандидаты\nвсё же указывают свои хобби. Зачем это делают?\n\nУвлечения вроде «просмотр сериалов», «путешествия» не требует особых\nусилий, нужны только свободное время, деньги и желание. Но есть такие\nхобби, которые могут добавить «плюсик» кандидату, показать его в\nвыгодном свете и «подсветить» нужные для работы навыки. Перед тем, как\nдобавлять что-то в этот раздел, ответьте себе на вопрос: отражает ли\nхобби те личные качества или умения, которые особо ценны для данной\nдолжности? Если да, то укажите, только не переусердствуйте: информации о\nваших интересах не должно быть много. Лучше рассказать подробнее на\nинтервью о них, чем забирать внимание с более важных для работодателя\nпунктов в резюме.\n\nНапример, если ищут «командного игрока с хорошими управленческими\nспособностями» --- то, что вы капитан команды по баскетболу, 
# ...

# %%
split_docs2 = text_splitter.split_documents(docs)

# %%
split_docs[10].page_content
# Out:
# 'и, сроками и качественными изменениями.\nОбычно для этого берут отрезки по полгода и указывают достижения за\nкаждый из них. Например, поработали год на проекте и вывели на рынок\nновый продукт с этапа идеи до продакшн за один месяц, или уменьшили\nколичество багов в продакшн в два раза (для QA).\n\nВ IT работают в командах и чаще встречаются командные достижения.\nНапример, ускорили time to market, выпустили 10 новых фич в течении\nгода, превысили скорость разработки на 10%, привели больше клиентов или\nотмасштабировались х10 по объему. Не стесняйтесь указывать командные\nдостижения.\n\n<junior>\nЧто делать новичкам? Указывайте за достижения все, что можете.\n* Прочитанные книги, курсы и тестовые задания.\n* Свои проекты: приложения, сайты-портфолио или настроенный домашняя\nсистема автополива кактуса на Arduino.\n* Участие в митапах, конференциях или хакатонах. Добавляйте результат\nхакатона в резюме и оно уже не пустое.\n\nНеважно на каком вы уровне се�'

# %%
max([len(doc.page_content) for doc in split_docs if len(doc.page_content)>1])
# Out:
# 1312

# %% [markdown]
# # Обработка резюме с помощью полученной базы знаний. Аналог нейро контроля качества

# %% [markdown]
# ## Наработки Лабзин Вячеслав

# %%
promt = """\
Ты профессиональный рекрутер по IT специальностям. У тебя большой опыт по составлению грамотных резюме, чтобы они привлекали внимание работодателей в IT сфере.
У тебя есть образец правильно составленного резюме.

К тебе будут поступать резюме выпускников IT университета.
Проверь заполнение каждого блока резюме. Проверь релевантность указанной информации, насколько указанная информация соответствует IT специальности.

Сравни резюме с образцом правильно составленного резюме.
В резюме должны быть заполнены блоки, как в образце правильно составленного резюме: Контакты, О себе, Навыки, Профессиональная деятельность, Образование.

В блоке “Навыки” должны быть указаны IT навыки.
Если блок “Навыки” не заполнен, обязательно укажи в ответе примеры IT навыков: Python, C++, Java, NumPy, Pandas, Matplotlib, Seaborn, Librosa, Gensim, Pymorphy2, Scikit-learn, SciPy, Keras, Pytorch

Укажи, если в каком-нибудь блоке резюме не указана информация.
Указывай только те блоки, в которых нет информации или информация не соответствует IT специальности. Не придумывай ничего от себя и лишнее в ответ не добавляй.
"""

# %%
response = openai.ChatCompletion.create(
  model="gpt-3.5-turbo",
  messages=[
        {"role": "system", "content": f"{system} \n\nОбразец правильно составленного резюме: {resume_sample}"},
        {"role": "user", "content": f" Кратко укажи замечания по заполнению резюме: {resume_none_educ}."},
        {"role": "assistant", "content": "В резюме не заполнен блок Образование. Добавьте свое образование, связанное с IT специальностями."},
        {"role": "user", "content": f"Кратко укажи замечания по заполнению резюме: {resume_none_skills}."}
    ]
)

answer = insert_newlines(response['choices'][0]['message']['content'])
print(answer)

# %%
# Для подачи в user-assistant, чтобы показать пример, какие вопросы будут поданы в user (Обратите внимание на последнюю строку)
topic3 = '''Вот список вопросов, которые надо задать клиенту. Задавай вопросы по порядку, по одному. Ни в коем случае не перечисляй сразу все вопросы. Называй только один вопрос.
{'1 ФИО': ' '},
{'2 адрес': ' '},
{'3 номер телефона': ' '},
{'4 адрес электронной почты': ' '},
{'5 краткое описание вашей профессиональной роли или цели, например "Full Stack разработчик" или "Data Scientist"': ' '},
{'6 ключевые технологии, с которыми работал клиент. Надо выбрать из перечня: Python, R, SQL, базовые знания статистики, машинное обучение, обработка данных, программная разработка': ' '},
{'7 опыт работы - проекты, в которых клиент принимал участие': ' '},
{'8 достижения - сертификаты, награды, если они есть у клиента': ' '},
{'9 образование - название учебного заведения': ' '},
{'10 специализация в учебном заведении': ' '},
{'11 год окончания учебного заведения': ' '},
{'12 дополнительные курсы или сертификаты, которые относятся к IT': ' '},
{'13 опыт работы - название компании': ' '},
{'14 опыт работы - должность': ' '},
{'15 период работы': ' '},
{'16 краткое описание обязанностей и достижений': ' '},
{'17 знание языков программирования, указать уровень владения (начинающий, средний, продвинутый)': ' '},
{'18 знание фреймворков, указать уровень владения (начинающий, средний, продвинутый)': ' '},
{'19 знание баз данных, указать уровень владения (начинающий, средний, продвинутый)': ' '},
{'20 знание операционных систем, указать уровень владения (начинающий, средний, продвинутый)': ' '},
{'21 знание английского языка': ' '},
{'22 командная работа': ' '},
{'23 умение решать проблемы': ' '},
{'24 рекомендации от предыдущих работодателей или коллег. Надо указать их контактные данные': ' '}
Задавай вопросы из словаря по порядку, по одному, начиная с самого первого без ответа.
После ответа клиента заполни пропуски, вставь вместо пробелов ' ' полученные ответы клиента.
В каждом своем ответе говори какие пункты словаря заполнены и задай новый вопрос клиенту для заполнения следующего пункта словаря.
Ни в коем случае в своем ответе не перечисляй все вопросы. Задавай только один вопрос.
Про пустые пункты словаря в своем ответе не говори.

Ответ клиента: Привет! Иванов Вячеслав Владимирович г. Москва, ул Профессиональная, дом 5'''

# %%
# Для подачи в assistant, чтобы показать пример, какие ответы должны быть от GPT
answer1 = 'Привет! Я профессиональный рекрутер. Я помогу Вам составить резюме. Скажите Ваше ФИО.'
answer2 = '{"1 ФИО": "Иванов Вячеслав Владимирович"} Следующий вопрос. Какой Ваш адрес?'
answer3 = '{"1 ФИО": "Иванов Вячеслав Владимирович"} {"2 адрес": "г. Москва, ул Профессиональная, дом 5"} Следующий вопрос. Ваш номер телефона?'

# %%
user_question = ''
answer = ''
while True:
    input_question = input('Клиент: ') + ' '
    if input_question.lower() == 'stop ':
        break
    user_question += input_question
    # topic = topic0 + user_question
    topic = f'{topic0} \n\n Предыдущий диалог: {answer} \n\n Ответ клиента: {input_question}'
    answer0 = answer_index(system_doc, topic1, answer1, topic2, answer2, topic3, answer3, topic)
    answer += answer0

    # dialog += f'\nКлиент: {user_question} \n Рекрутер: {answer}'
    print('\nРекрутер: ', answer0)
# Out:
# Клиент: Привет!
#
# Рекрутер:   Привет! Благодарю за ответы на предыдущие вопросы. Я заполнил информацию о ФИО и адресе. Теперь мне нужна Ваша адрес электронной почты.
# Клиент: Ivanov@mail.ru
#
# Рекрутер:   {"4 адрес электронной почты": "Ivanov@mail.ru"} Благодарю за предоставленную информацию. Следующий вопрос - краткое описание вашей профессиональной роли или цели.
#  Например, вы бы хотели стать Full Stack разработчиком или Data Scientist?
# Клиент: Data Scientist
#
# Рекрутер:   {"4 адрес электронной почты": "Ivanov@mail.ru"} {"5 краткое описание вашей профессиональной роли или цели": "Data Scientist"} Спасибо за информацию. Следующий вопрос - с
#  какими ключевыми технологиями Вы работали? Можете выбрать из списка: Python, R, SQL, базовые знания статистики, машинное обучение, обработка данных, программная
#  разработка.
# Клиент: Python, R, SQL, машинное обучение
#
# ...

# %%
# Итог диалога рекрутера с клиентом
print (answer0)
# Out:
#  {"1 ФИО": "Иванов Вячеслав Владимирович"} {"2 адрес": "г. Москва, ул Профессиональная, дом 5"} {"3 номер телефона": " "} {"4 адрес электронной почты": "Ivanov@mail.ru"}
#  {"5 краткое описание вашей профессиональной роли или цели": "Data Scientist"} {"6 ключевые технологии, с которыми работал клиент": "Python, R, SQL, машинное обучение"}
#  {"7 опыт работы - проекты, в которых клиент принимал участие": "Создание нейро-консультанта"} {"8 достижения - сертификаты, награды, если они есть у клиента": "Занял
#  третье место в хакатоне по искусственному интеллекту"} {"9 образование - название учебного заведения": "Южный федеральный университет"} {"10 специализация в учебном
#  заведении": "Прикладная математика и информатика"} {"11 год окончания учебного заведения": "2011"} {"12 дополнительные курсы или сертификаты, которые относятся к IT":
# ...

# %%
# Инструкция для GPT, которая будет подаваться в system
system_doc= '''Ты профессиональный рекрутер, который составляет резюме для трудоустройства клиента в IT компанию.
У тебя большой опыт по составлению грамотных резюме, чтобы они привлекали внимание работодателей в IT сфере.
У тебя есть образец резюме.

К тебе будет поступать информация клиента. Информация клиента будет представлена в виде словаря.
Из представленной информации составь грамотное резюме.

При составлении резюме добавь переносы строк, чтобы резюме выглядело также, как образец резюме.
 '''

# %%
print (resume_sample)
# Out:
# ﻿Вячеслав Лабзин
# Data Scientist
# КОНТАКТЫ
#
#
# +7(499)-123-47-85
# labzin@mail.ru
#
#
# О СЕБЕ
#
#
# Я Junior специалист в сфере искусственного интеллекта. Имею опыт работы с анализом данных, разработкой нейронных сетей.
# Активно изучаю и работаю с ChatGPT.
#
#
# НАВЫКИ
#
#
# Python, GPT (языковое моделирование), NumPy, Pandas, Matplotlib, Seaborn, Keras,Tensorflow
#
#
# ПРОФЕССИОНАЛЬНАЯ ДЕЯТЕЛЬНОСТЬ
#
#
# Проект: Создание веб-сайта для генерации резюме и сопроводительных писем
#
#
#
# Проект: Разработка нейронной сети для обработки данных горного эндоскопа
#
#
#
# 2016 - сейчас
# ООО «КЗ «Ростсельмаш»
#
#
# ГЛАВНЫЙ СПЕЦИАЛИСТ МАТЕРИАЛЬНО-ТЕХНИЧЕСКОГО СНАБЖЕНИЯ ПО ЦЕНООБРАЗОВАНИЮ
#
#
# * проверка и согласование цен на покупные товарно-материальные ценности
#
#
#
#
# ОБРАЗОВАНИЕ
#
#
# 2023
# УНИВЕРСИТЕТ ИСКУССТВЕННОГО ИНТЕЛЛЕКТА
# * Chat GPT Professional
# * Data Science и нейронные сети

# %%
# Для подачи в user-assistant, чтобы показать пример, какой диалог будет подан в user
dialog_sample = '''
{'1 ФИО': 'Вячеслав Лабзин'} {'2 краткое описание вашей профессиональной роли или цели, например "Full Stack разработчик" или "Data Scientist"': 'Data Scientist'}
{'3 номер телефона': '+7(499)-123-47-85'} {'4 адрес электронной почты': 'labzin@mail.ru'}
{'5 О себе': 'Я Junior специалист в сфере искусственного интеллекта. Имею опыт работы с анализом данных, разработкой нейронных сетей.
Активно изучаю и работаю с ChatGPT.'}
{'6 ключевые технологии, с которыми работал клиент. Надо выбрать из перечня: Python, R, SQL, базовые знания статистики, машинное обучение, обработка данных, программная разработка': 'Python, GPT (языковое моделирование), NumPy, Pandas, Matplotlib, Seaborn, Keras,Tensorflow'},
{'7 опыт работы - проекты, в которых клиент принимал участие': 'Создание веб-сайта для генерации резюме и сопроводительных писем; Разработка нейронной сети для обработки данных горного эндоскопа'},
{'8 достижения - сертификаты, награды, если они есть у клиента': ' '} {'9 опыт работы - название компании': 'ООО «КЗ «Ростсельмаш»'}
{'10 опыт работы - должность': 'ГЛАВНЫЙ СПЕЦИАЛИСТ МАТЕРИАЛЬНО-ТЕХНИЧЕСКОГО СНАБЖЕНИЯ ПО ЦЕНООБРАЗОВАНИЮ'} {'11 период работы': '2016 - сейчас'}
{'12 краткое описание обязанностей и достижений': 'проверка и согласование цен на покупные товарно-материальные ценности'}
{'13 образование - название учебного заведения': 'УНИВЕРСИТЕТ ИСКУССТВЕННОГО ИНТЕЛЛЕКТА'} {'14 специализация в учебном заведении': 'Chat GPT Professional; Data Science и нейронные сети'}
{'15 год окончания учебного заведения': '2023'}
'''

# %%
response = openai.ChatCompletion.create(
  model="gpt-3.5-turbo",
  messages=[
        {"role": "system", "content": f'{system_doc} \n\nОбразец резюме: {resume_sample}'},
        {"role": "user", "content": f"Составь резюме из диалога: \n\n{dialog_sample}. Информацию \
        для резюме бери только из диалога. Если в диалоге информации нет, ставь пропуски. От \
        себя ничего не добавляй."},
        {"role": "assistant", "content": resume_sample},
        {"role": "user", "content": f"Составь резюме из диалога: \n\n{dialog}. Информацию для резюме\
         бери только из диалога. Если в диалоге информации нет, ставь пропуски. От себя ничего не\
          добавляй."}
    ]
)
answer = response['choices'][0]['message']['content']
print(answer)
# Out:
# ﻿Иванов Вячеслав Владимирович
# Data Scientist
# КОНТАКТЫ
#
#
# +7(XXX)XXXXXXX
# Ivanov@mail.ru
#
#
# О СЕБЕ
#
#
#
#
#
# НАВЫКИ
#
#
# Python, R, SQL, машинное обучение
#
#
# ПРОФЕССИОНАЛЬНАЯ ДЕЯТЕЛЬНОСТЬ
#
#
# Проект: Создание нейро-консультанта
#
#
#
# Третье место в хакатоне по искусственному интеллекту
#
#
#
#
# 2015 - настоящее время
# ПАО ГАЗ
#
#
# Главный технолог
#
#
# *
#
#
# ОБРАЗОВАНИЕ
#
#
# 2011
# Южный федеральный университет
# * Прикладная математика и информатика
#
#
# ДОПОЛНИТЕЛЬНЫЕ КУРСЫ И СЕРТИФИКАТЫ
#
#
# курс по машинному обучению

# %% [markdown]
# ## доработка с использованием базы знаний

# %%
ex = "\n".join([f"{key}: {str(value)[7:-1]}" for key,value in resume.to_dict().items()])
print(ex)
# Out:
# Пол, возраст: 'Мужчина ,  22 года , родился 25 декабря 1996'
# ЗП: '80000 руб.'
# Ищет работу на должность:: 'data scientist'
# Город: 'Москва ,  м. Дмитровская , готов к переезду , готов к командировкам'
# Занятость: 'частичная занятость, полная занятость'
# График: 'гибкий график, полный день'
# ...

# %%
ex
# Out:
# "Пол, возраст: 'Мужчина ,  22 года , родился 25 декабря 1996'\nЗП: '80000 руб.'\nИщет работу на должность:: 'data scientist'\nГород: 'Москва ,  м. Дмитровская , готов к переезду , готов к командировкам'\nЗанятость: 'частичная занятость, полная занятость'\nГрафик: 'гибкий график, полный день'\nОпыт (двойное нажатие для полной версии): 'Опыт работы 11 месяцев  Data Scientist 80 000 руб. Информационные технологии, интернет, телеком Программирование, Разработка Аналитик Занятость: частичная занятость, полная занятость График работы: гибкий график, полный день Опыт работы 11 месяцев Декабрь 2018 — по настоящее время 5 месяцев Clustech Junior data scientist Работаю с временными рядами Июнь 2018 — Август  2018 3 месяца OZON Москва , www.ozon.ru Розничная торговля ... Розничная сеть (книги, игрушки, подарки, часы и прочее) СМИ, маркетинг, реклама, BTL, PR, дизайн, продюсирование Издательская деятельность Производство печатной, полиграфической продукции Стажер, Data Scientist Учавствовал в пр
# ...

# %%
"""{'Пол, возраст': {4848: 'Мужчина ,  22 года , родился 25 декабря 1996'}, 'ЗП': {4848: '80000 руб.'}, 'Ищет работу на должность:': {4848: 'data scientist'}, 'Город': {4848: 'Москва ,  м. Дмитровская , готов к переезду , готов к командировкам'}, 'Занятость': {4848: 'частичная занятость, полная занятость'}, 'График': {4848: 'гибкий график, полный день'}, 'Опыт (двойное нажатие для полной версии)': {4848: 'Опыт работы 11 месяцев  Data Scientist 80 000 руб. Информационные технологии, интернет, телеком Программирование, Разработка Аналитик Занятость: частичная занятость, полная занятость График работы: гибкий график, полный день Опыт работы 11 месяцев Декабрь 2018 — по настоящее время 5 месяцев Clustech Junior data scientist Работаю с временными рядами Июнь 2018 — Август  2018 3 месяца OZON Москва , www.ozon.ru Розничная торговля ... Розничная сеть (книги, игрушки, подарки, часы и прочее) СМИ, маркетинг, реклама, BTL, PR, дизайн, продюсирование Издательская деятельность Производство печатной, полиграфической продукции Стажер, Data Scientist Учавствовал в проекте по автоматизации системы закупок. В рамках которого: - Обрабатывал данные - Формировал датасеты - Обучал модели - Писал продакшн код - Настраивал ec2 instances на AWS, для обучения моделей и экспериментов Июнь 2017 — Август  2017 3 месяца Сбербанк www.sbrf.ru Финансовый сектор ... Банк Стажер в департаменте внутреннего аудита В процессе прохождение стажировки, помимо прочего, участвовал во внутреннем конкурсе по анализу данных. Ключевые навыки Теперь резюме открыто всему интернету — изменить можно в настройках видимости. Python PySpark Pandas Numpy Scipy xgboost lgbm Git Linux Bash SQL Keras Возникли неполадки. Попробуйте еще раз. Обо мне Github - https://github.com/RomanMatiiv Активно участвую в хакатонах и митапах по Data Science Неоконченное высшее образование 2019 Кликнув на название учебного заведения вы сможете найти кандидатов из этого вуза. Финансовый университет при Правительстве Российской Федерации, Москва Прикладная математка и информационные технологии, Прикладная информатика Знание языков Русский — Родной Английский — B2 — Средне-продвинутый Повышение квалификации, курсы 2018 Машинное обучение и анализ данных МФТИ и Yandex на платформе Coursera, Data Science 2018 Data Mining In Action Advanced Digital Sciences Center, Индустриальный анализ данных 2017 Введение в машинное обучение HSE & Yandex School of Data Analysis на платформе Coursera, Data Science 2017 ML course open Open Data Science, Data Science 2016 Технологии машинного обучения в финансовой сфере КПМГ и Майкрософт Гражданство, время в пути до работы Гражданство: Россия Разрешение на работу: Россия Желательное время в пути до работы: Не имеет значения  Опыт работы 11 месяцев Декабрь 2018 — по настоящее время 5 месяцев Clustech Junior data scientist Работаю с временными рядами Июнь 2018 — Август  2018 3 месяца OZON Москва , www.ozon.ru Розничная торговля ... Розничная сеть (книги, игрушки, подарки, часы и прочее) СМИ, маркетинг, реклама, BTL, PR, дизайн, продюсирование Издательская деятельность Производство печатной, полиграфической продукции Стажер, Data Scientist Учавствовал в проекте по автоматизации системы закупок. В рамках которого: - Обрабатывал данные - Формировал датасеты - Обучал модели - Писал продакшн код - Настраивал ec2 instances на AWS, для обучения моделей и экспериментов Июнь 2017 — Август  2017 3 месяца Сбербанк www.sbrf.ru Финансовый сектор ... Банк Стажер в департаменте внутреннего аудита В процессе прохождение стажировки, помимо прочего, участвовал во внутреннем конкурсе по анализу данных.  Декабрь 2018 — по настоящее время 5 месяцев Clustech Junior data scientist Работаю с временными рядами  Июнь 2018 — Август  2018 3 месяца OZON Москва , www.ozon.ru Розничная торговля ... Розничная сеть (книги, игрушки, подарки, часы и прочее) СМИ, маркетинг, реклама, BTL, PR, дизайн, продюсирование Издательская деятельность Производство печатной, полиграфической продукции Стажер, Data Scientist Учавствовал в проекте по автоматизации системы закупок. В рамках которого: - Обрабатывал данные - Формировал датасеты - Обучал модели - Писал продакшн код - Настраивал ec2 instances на AWS, для обучения моделей и экспериментов  Июнь 2017 — Август  2017 3 месяца Сбербанк www.sbrf.ru Финансовый сектор ... Банк Стажер в департаменте внутреннего аудита В процессе прохождение стажировки, помимо прочего, участвовал во внутреннем конкурсе по анализу данных.'}, 'Последенее/нынешнее место работы': {4848: 'Clustech'}, 'Последеняя/нынешняя должность': {4848: 'Junior data scientist'}, 'Образование и ВУЗ': {4848: 'Неоконченное высшее образование 2019  Финансовый университет при Правительстве Российской Федерации, Москва Прикладная математка и информационные технологии, Прикладная информатика'}, 'Обновление резюме': {4848: '28.03.2019 13:04'}, 'Авто': {4848: 'Не указано'}}"""

# %%
Пол, возраст: 'Мужчина ,  22 года , родился 25 декабря 1996'
ЗП: '80000 руб.'
Ищет работу на должность:: 'data scientist'
Город: 'Москва ,  м. Дмитровская , готов к переезду , готов к командировкам'
Занятость: 'частичная занятость, полная занятость'
График: 'гибкий график, полный день'
Опыт (двойное нажатие для полной версии): 'Опыт работы 11 месяцев  Data Scientist 80 000 руб. Информационные технологии, интернет, телеком Программирование, Разработка Аналитик Занятость: частичная занятость, полная занятость График работы: гибкий график, полный день Опыт работы 11 месяцев Декабрь 2018 — по настоящее время 5 месяцев Clustech Junior data scientist Работаю с временными рядами Июнь 2018 — Август  2018 3 месяца OZON Москва , www.ozon.ru Розничная торговля ... Розничная сеть (книги, игрушки, подарки, часы и прочее) СМИ, маркетинг, реклама, BTL, PR, дизайн, продюсирование Издательская деятельность Производство печатной, полиграфической продукции Стажер, Data Scientist Учавствовал в проекте по автоматизации системы закупок. В рамках которого: - Обрабатывал данные - Формировал датасеты - Обучал модели - Писал продакшн код - Настраивал ec2 instances на AWS, для обучения моделей и экспериментов Июнь 2017 — Август  2017 3 месяца Сбербанк www.sbrf.ru Финансовый сектор ... Банк Стажер в департаменте внутреннего аудита В процессе прохождение стажировки, помимо прочего, участвовал во внутреннем конкурсе по анализу данных. Ключевые навыки Теперь резюме открыто всему интернету — изменить можно в настройках видимости. Python PySpark Pandas Numpy Scipy xgboost lgbm Git Linux Bash SQL Keras Возникли неполадки. Попробуйте еще раз. Обо мне Github - https://github.com/RomanMatiiv Активно участвую в хакатонах и митапах по Data Science Неоконченное высшее образование 2019 Кликнув на название учебного заведения вы сможете найти кандидатов из этого вуза. Финансовый университет при Правительстве Российской Федерации, Москва Прикладная математка и информационные технологии, Прикладная информатика Знание языков Русский — Родной Английский — B2 — Средне-продвинутый Повышение квалификации, курсы 2018 Машинное обучение и анализ данных МФТИ и Yandex на платформе Coursera, Data Science 2018 Data Mining In Action Advanced Digital Sciences Center, Индустриальный анализ данных 2017 Введение в машинное обучение HSE & Yandex School of Data Analysis на платформе Coursera, Data Science 2017 ML course open Open Data Science, Data Science 2016 Технологии машинного обучения в финансовой сфере КПМГ и Майкрософт Гражданство, время в пути до работы Гражданство: Россия Разрешение на работу: Россия Желательное время в пути до работы: Не имеет значения  Опыт работы 11 месяцев Декабрь 2018 — по настоящее время 5 месяцев Clustech Junior data scientist Работаю с временными рядами Июнь 2018 — Август  2018 3 месяца OZON Москва , www.ozon.ru Розничная торговля ... Розничная сеть (книги, игрушки, подарки, часы и прочее) СМИ, маркетинг, реклама, BTL, PR, дизайн, продюсирование Издательская деятельность Производство печатной, полиграфической продукции Стажер, Data Scientist Учавствовал в проекте по автоматизации системы закупок. В рамках которого: - Обрабатывал данные - Формировал датасеты - Обучал модели - Писал продакшн код - Настраивал ec2 instances на AWS, для обучения моделей и экспериментов Июнь 2017 — Август  2017 3 месяца Сбербанк www.sbrf.ru Финансовый сектор ... Банк Стажер в департаменте внутреннего аудита В процессе прохождение стажировки, помимо прочего, участвовал во внутреннем конкурсе по анализу данных.  Декабрь 2018 — по настоящее время 5 месяцев Clustech Junior data scientist Работаю с временными рядами  Июнь 2018 — Август  2018 3 месяца OZON Москва , www.ozon.ru Розничная торговля ... Розничная сеть (книги, игрушки, подарки, часы и прочее) СМИ, маркетинг, реклама, BTL, PR, дизайн, продюсирование Издательская деятельность Производство печатной, полиграфической продукции Стажер, Data Scientist Учавствовал в проекте по автоматизации системы закупок. В рамках которого: - Обрабатывал данные - Формировал датасеты - Обучал модели - Писал продакшн код - Настраивал ec2 instances на AWS, для обучения моделей и экспериментов  Июнь 2017 — Август  2017 3 месяца Сбербанк www.sbrf.ru Финансовый сектор ... Банк Стажер в департаменте внутреннего аудита В процессе прохождение стажировки, помимо прочего, участвовал во внутреннем конкурсе по анализу данных.'
Последенее/нынешнее место работы: 'Clustech'
Последеняя/нынешняя должность: 'Junior data scientist'
Образование и ВУЗ: 'Неоконченное высшее образование 2019  Финансовый университет при Правительстве Российской Федерации, Москва Прикладная математка и информационные технологии, Прикладная информатика'
Обновление резюме: '28.03.2019 13:04'
Авто: 'Не указано'

# %%
hr_text = """\
Составление резюме

Наличие правильно оформленного резюме является важным этапом поиска работы. Грамотно составленное резюме поможет вам выделиться среди других кандидатов и привлечь внимание работодателя. Далее, мы рассмотрим различные разделы резюме и дадим рекомендации по их правильному составлению.

1.
Первым разделом резюме является "Персональная информация". В этом разделе необходимо указать свою фамилию, имя и контактную информацию - номер телефона, телеграмм, электронную почту. Важно указать актуальные контактные данные, чтобы работодатель мог связаться с вами.

2.
Следующим разделом является “Желаемая должность”. Должность  должна быть конкретной и соответствовать вакансии, на которую вы откликаетесь. Например, если вы ищете работу в IT- сфере, то должность может звучать как “Data Science” или “AI-Engineer”.

3.
Укажите ссылку на ваш GitHub с выполненными проектами. Данный репозиторий является визитной карточкой специалистов в сфере IT. Если вы еще не создали свою страницу на данной платформе, то это необходимо сделать и отобразить ссылку в верхней части резюме. Правильно оформленный профиль на GitHub очень важен для поиска работы.

4.
В разделе "Навыки" необходимо описать свои навыки, которые помогут вам развиваться в выбранной области, данный раздел позволит работодателю быстро оценить ваши профессиональные компетенции и определить, подходите ли вы для конкретной вакансии. В этом разделе вы должны указать технические навыки, которыми вы обладаете. Например: Python,  Numpy,  Pandas,  Matplotlib и т.д.

Ваши технические навыки могут включать знание языков программирования, фреймворков, баз данных и других инструментов, которые вы использовали в своей работе. Важно указывать только те навыки, которыми вы действительно владеете на достаточно высоком уровне.

5.
Раздел “Хакатоны”. Участие в хакатонах всегда говорит о вас, как о кандидате, который постоянно развивает свои навыки, умеет работать в команде и следит за стремительно развивающейся сферой IT. Если вы участвовали в хакатонах, то эту информацию необходимо внести в резюме - даты проведения, организатора, название проекта над которым работали, задачи, которые решили и ссылку на сертификат участника.

6.
Следующий раздел - "Опыт работы". В этом разделе необходимо описать свой опыт работы, основываясь на достигнутых результатах и достижениях. Важно предоставить конкретные цифры и факты, которые подтвердят вашу экспертность. Раздел должен быть информативным, конкретным и лаконичным. Данный раздел является одним из самых важных в резюме, поскольку он позволяет работодателю оценить, насколько соискатель подходит для конкретной вакансии, необходимо предоставить только релевантную информацию, связанную с вакансией, на которую вы претендуете. В этом разделе необходимо указать предыдущие места работы за последние 10 лет, начиная с последнего и двигаясь в обратном хронологическом порядке.
Вот несколько советов о том, как грамотно составить раздел "Опыт работы" в резюме:

1. Первое, что стоит описать в разделе “Опыт работы” - это "Проекты". Если у вас были проекты, которые вы разработали или внедрили, укажите их. Необходимо описать задачи, которые вы выполняли в рамках каждого проекта.
Например: "Разработал и внедрил корпоративную CRM-систему, которая позволила ускорить все рабочие процессы и организовать работу отдела с нуля", используемые технологии и достигнутые результаты.
Если у вас был опыт работы в крупных проектах или с известными компаниями, укажите это. Например: "Написал и обеспечил поддержку крупного банковского проекта на Spring MVC".

2. Если у вас были стажировки, то укажите их и опишите, какие задачи вы выполняли и какие навыки приобрели. Например: "Стажер в IT-компании, работал над разработкой веб-приложений на языке Python".

3. Начните описывать опыт с указания названия компании, где вы работали, и даты вашего трудоустройства. Например: , 09. 2019 - настоящее время, Инженер-разработчик (Senior), Команда платежной системы, ООО “Быстрое Такси”.

4. Опишите свои основные обязанности и достижения. Опишите свои конкретные достижения на каждой позиции в глаголах-действиях.
Например: "Написал и обеспечил поддержку приложения на Java, включая прошивку устройства и интеграцию с серверными системами и мобильным приложением" или  "Внедрил ПО, с помощью которого было пресечено 25 фактов мошенничества".

5. Укажите ключевые навыки и технологии, которыми вы пользовались во время работы. Например: "Языки программирования: Java, Go, Swift, Python".

6. Если у вас были периоды безработицы или работы на фрилансе, укажите их и опишите, какие проекты вы выполняли в этот период. Например: "Фрилансер, работал над разработкой мобильных приложений на платформе Android".
При составлении раздела "Опыт работы" важно учитывать требования вакансии. Подчеркните те навыки и достижения, которые наиболее соответствуют требованиям работодателя. Это поможет выделиться среди других кандидатов и показать свою ценность для конкретной вакансии и компании.
Также, не забывайте оформить раздел "Опыт работы" визуально привлекательно и структурировано. Используйте пункты или нумерацию, чтобы сделать информацию более читабельной. Разделите каждую позицию на отдельные абзацы или используйте маркированные списки для более ясного представления информации.


7.
В разделе "Образование" необходимо указать учебные заведения, в которых вы учились, и специальности, которые вы получили. Кроме того, в разделе "Образование" вы можете добавить блок с описанием конференций, курсов и других образовательных мероприятий, которые вы посещали. Это позволит показать ваше стремление к саморазвитию и постоянное обучение, что является важным качеством для работодателей.

8.
В разделе "Дополнительная информация" можно указать дополнительные навыки, которые могут быть полезны в выбранной области. Например, вы можете указать знание иностранных языков или ваши публикации и статьи.

Важно помнить, что резюме должно быть емким, лаконичным и легко читаемым. Используйте подходящий шрифт и размер текста, чтобы резюме было максимально читабельным. Не используйте больше двух - трех шрифтов. Также стоит обратить внимание на оформление резюме, чтобы оно было привлекательным и профессиональным.

В заключение, грамотно составленное резюме - это важный этап в поиске работы. Правильно составленное резюме поможет выделиться среди других кандидатов и привлечь внимание работодателя. Следуйте рекомендациям по составлению каждого раздела резюме и не забывайте адаптировать его под каждую конкретную вакансию.

"""

# %%
Власов Владимир

Мужчина


+7 (908) 2654130

vip.v2a@gmail.com


Проживает: Пермь

Гражданство: Россия, есть разрешение на работу: Россия

Не готов к переезду, готов к редким командировкам

Желаемая должность и зарплата

Программист Python

Специализации:

Программист, разработчик

Занятость: полная занятость, частичная занятость, проектная работа

График работы: полный день, удаленная работа

Желательное время в пути до работы: не имеет значения

Опыт работы — 1 год 1 месяц:

Университет искусственного интеллекта
Москва

Образовательные учреждения

Повышение квалификации, переквалификация
Август 2023 — настоящее время 4 месяца

Promt инженер, python разработчик

Создание сайта конструктора резюме в сфере Data Science и Python-разработки при поддержке ChatGPT.
Цель проекта - создать удобный и приятный инструмент для студентов и выпускников УИИ по составлению резюме.
Выполненные задачи:
- создание базы знаний для chatGPT на основе документов HR-отдела;
- создание структуры базы данных для хранения резюме на основании информации из базы знаний;
- создание алгоритма проверки заполнения разделов резюме на соответствие требованиям из документов HR-отдела с использованием chatGPT и LangChain.

Хакатон "Humans VS AI"
Март 2023 — Март 2023 1 месяц

Data Scientist

Задача хакатона: определить кем был написан текст: человеком или ChatGPT.
- Разрабатывал фичи для улучшения качества классификации текстов
- Использовал в решении несколько библиотек и инструментов для улучшения качества классификации: NLTK, spacy, pymorphy, HuggingFace модели

Моторика
Июль 2022 — Октябрь 2022 4 месяца

Data Scientist

Определение жеста руки по показаниям с датчиков:
- создал модели классификации жестов на основе методов классического машинного обучения и на основе глубокого обучения с применением сверточных слоев
- придумывал новые фичи для улучшения качества классификации жестов

Clovery
Июль 2021 — Октябрь 2021 4 месяца

Data Scientist

Перед нами стояла цель создания агрегатора вакансий на основе данных из различных источников:
- классификация вакансий на 20+ профессий
- применение бинарных классификаций для улучшения качества классификации профессий: определение, что данный текст является вакансией; определение, что вакансия является вакансией в сфере IT
- извлечение из текста вакансии номеров телефонов, адресов электронной почты, желаемого уровня зарплаты, валюты, опыта работы и других данных

Образование:

Высшее

Eduson
2024
Python-разработчик

Eduson
2023
Аналитик данных

Универстет искусственного интеллекта
2020
Data Science

Пермский национальный исследовательский политехнический университет, Пермь
2014
ЭТФ, АТПП-09

Ключевые навыки:

Знание языков
Русский — Родной
Английский — A2 — Элементарный
Навыки
Python; PostgreSQL; Pandas; Numpy; NLP; ChatGPT; LangChain; Визуализация; Seaborn; Matplotlib; Hugging Face; REGEX; Catboost; Machine Learning; Keras; API; Telegram bot; Excel; Power BI; sklearn; NLTK

# %%
"ChatGPT, пожалуйста, ознакомься с рекомендациями HR-отдела по составлению резюме, которые я предоставлю ниже.

[вставить рекомендации HR-отдела]

Также я предоставлю тебе первые 2 абзаца раздела "Опыт работы" из резюме Иванова Ивана. Пожалуйста, проверь эти абзацы на соответствие рекомендациям HR и укажи конкретные замечания.

[вставить 2 абзаца раздела "Опыт работы"]"

Этап 2. Внесение изменений на основе замечаний:

"ChatGPT, на предыдущем этапе ты дал следующие замечания к разделу "Опыт работы" резюме: [перечислить замечания].

Пожалуйста, предложи, как оптимально изменить текст этих 2 абзацев с учетом замечаний и рекомендаций HR-отдела.

# %% [markdown]
# ## Пример хороших резюме от HR

# %% [markdown]
# ИВАН ИВАНОВИЧ
#
# Data Scientist
#
# https://github.com/...
#
#
# О СЕБЕ
#
# Начинающий специалист в области Data Science с желанием развиваться в сфере искусственного интеллекта.
# Мои амбиции и целеустремленность помогут мне достичь успеха в этой увлекательной и стремительно развивающейся сфере. Готова взяться за любые задачи и
# направления работы, чтобы расширить свои знания и навыки.
#
#
# НАВЫКИ
#
# Python
# NumPy
# Pandas
# Matplotlib
# Seq-2-Seq
# GPT
# GAN
# Requests
# Docker
# FastAPI
#
#
# СОЗДАННЫЕ НС
# - НС, собранная при помощи
# генетического алгоритма для
# предсказания типа поведения
# человека
# - НС, собранная при помощи
# AutoML для предсказания типа
# поведения человека
# - НС для сегментации
# фотографий трещин в
# геологической скважине
# - НС для классификации типа
# поведения человека
# - Генетический алгоритм для
# оптимального распределения
# грузов по поездам
# - НС для классификации
# текстов писателей
# - НС для сегментации
# фотографий самолетов
# - НС для классификации
# "Пассажиров автобуса" по
# изображению
#
#
# ПРОФЕССИОНАЛЬНАЯ ДЕЯТЕЛЬНОСТЬ
#
# - Разработчик AI | 05.2023 – по настоящее время
# Российская академия наук
# Название проекта: Разработка нейронной сети для обработки данных
# горного эндоскопа, распознавание трещин в горном массиве
# - Разработчик telegramBot для Prodaction | 02.2023 – 05.2023
# ПАО «Ростелеком»
# Название проекта: Семантическая классификация деревьев
# - Создание telegramBot, который на вход принимает ссылку на файл с
# облаком точек и возвращает предсказание процентного содержания
# пород деревьев
# Результат: Разработан telegramBot
# Стек: Python, TelegramBot
# Фриланс / частная практика | 2022
# Название проекта: Бот-коуч
# Принимает вопросы на философские темы и отвечает на основании
# взглядов на жизнь двух коучей
# - Создание telegramBot, который использует базу знаний 2 коучей и
# ChatGPT
# Решение:
# - Собрана база знаний из постов в социальных сетях, сайте коучей и
# статей коучей в Яндекс.Дзен и загружена в документ на GoogleDoc
# - Код обработчика telegramBot размещен на VDS-сервере
# - В telegram создан telegramBot
# Стек: Python, ChatGPT, TelegramBot
# Ссылка на проект: ...
#
# - Инженер-проектировщик | 08.2013 – 10.2017
# ООО "ППК", г. Первоуральск
# - Разработка технической документации: разделы "Архитектурные
# решения", "Конструкции металлические", "Конструкции
# железобетонные"
# - Расчет сбора нагрузок
# - Подготовка документации для государственной экспертизы
# Достижения:
# - Спроектировала 3 детских сада, навес для трибун стадиона, пивзавод,
# спортивный зал
#
# ОБРАЗОВАНИЕ
#
# - Университет искусственного интеллекта, г. Москва | 2023
# «Data Science, нейронные сети, машинное обучение и
# искусственный интеллект»
# Дипломный проект: Классификация человека по типу поведения:
# одиночка или командный игрок
# - Предсказание образа, который представил пользователь на основании
# результатов, полученных при прохождении ассоциативного теста на
# testkub.ru
# - Разработка модели нейросетей, используя следующие методики:
# ручной подбор гиперпараметров, балансировка датасета, AutoML,
# генетический алгоритм
# - Размещение в Production на телеграм-боте
# Решенние: Доказано, что есть закономерность в образах, которые
# представляют пользователи - их предсказание с точностью 0.69
# Стек: Python, Pandas, Matplotlib, AutoML, генетический алгоритм,
# TelegramBot, FastAPI
# Ссылка на проект: ...
# Уральский федеральный университет им. первого Президента
# России Б.Н. Ельцина, г. Екатеринбург | 2013
# «Промышленное и гражданское строительство»
# Строительный факультет, специалист

# %% [markdown]
# ИВАН ИВАНОВИЧ
#
# Data Scientist
#
# https://github.com/...
#
#
# КОНТАКТЫ
# +7 (000) 000 - 00 – 00
# Иван Иванович.ru
# @Иван Иванович
#
# Начинающий специалист в сфере искусственного интеллекта. Увлечен AI как инструментом оптимизации технологических
# процессов и систематизации потоков данных в сферах строительства и производства. Cтремлюсь применять свои знания, навыки
# для решения сложных задач и развиваться в своей профессиональной сфере.
#
# НАВЫКИ
#
# Python
# NumPy
# Pandas
# Matplotlib
# Keras
# Pytorch
# Tensorflow
# GAN
# CGAN
# WGAN
# GIT
# Object Detection
# ООП
#
# СОЗДАННЫЕ НС
#
# НС для классификации "Пассажиров автобуса" по изображению с точностью более 90 процентов
# НС для сегментации фотографий стройки, самолетов
# Генетический алгоритм для оптимального распределения грузов по поездам
# НС для предсказания оценки зарплаты на базе HeadHunter
# НС для кластеризации базы HeadHunter
# НС, собранная при помощи генетического алгоритма для предсказания стоимости/тренда акций
# НС для удаления шума
# НС для определения мошеннических операций на датасете транзакций по кредитным картам
# НС для классификации базы обращений граждан
#
# ПРОФЕССИОНАЛЬНЫЙ ОПЫТ
#
# Стажер Data Science
# ПАО «КАМАЗ»
# 08.2022 - 01.2023
# Проект: «Контроль состояние водителя. Идентификация водителя»
# Задачи:
# Получение тестовых результатов от YoloV3
# Разработка блока «Распознавание сонливости, частота зевания, частота
# моргания (ключевые точки на лице), микросон, отвлечение взгляда.»
# Разработка визуализации результатов посредством Matplotlib и Seaborn
# Достижения:
# YoloV3 показала низкую точность распознавания в сравнении с YoloV5
# Блок распознавания состояний водителя на основе библиотек OpenCV и Dlib
# показал высокое качество определения изменений состояния водителя
# Блок отвлечения водителя на основе библиотек OpenCV и Dlib показал
# высокое качество обнаружения лица водителя в фронтальной проекции
# Визуализация результатов получилась информативной и помогла в анализе
# работы модели
# Стек - Python, Pandas, Numpy, Matplotlib, Math, Seaborn, Keras, Tensorflow
#
#
# Менеджер проекта в сфере проектирования и
# строительства коммерческой недвижимости
# OOO «СК СОЮЗ»; ООО «Гранит»; PRIDEX Group
# 07.2012 – по настоящее время
# Ведение заказа с момента получения ТЗ до подписания акта выполненных работ
# Помощь в разработке технического задания
# Курирование разработки рабочей документации, координация разработчиков
# разделов АР, ВК, ЭОМ, ОВИК, КМ, КЖ
# Проведение оценочных расчетов и подготовка бюджета объекта
# Закупка материалов
# Подбор подрядчиков и контроль сроков и качества услуг
# Контроль за соблюдением сроков и этапности работ
# Сдача объекта службам эксплуатации Заказчика и Арендодателя
#
#
# ОБРАЗОВАНИЕ
#
# Университет искусственного интеллекта
# 2023:
# «Data Science, нейронные сети, машинное обучение и искусственный интеллект»
# Дипломный проект: «Определение сорной растительности в сельскохозяйственных
# культурах»
# Сбор базы
# Подготовка и обработка базы
# Разметка и аугментация данных перед моделированием
# Обучение YoloV7, анализ обученных моделей
# Решенные задачи: Получилась модель, удовлетворительная по заданным
# заказчиком критериям качества предсказания
# Стек: Python, Pandas, Numpy, Matplotlib, Math, Seaborn, Keras, Tensorflow
# Ссылка на проект: ...
#
# Stepic
# 2022:
# «Поколение Python» курс для начинающих
# 2023:
# «Поколение Python» курс для продвинутых
# 2023:
# «Поколение Python» контесты по программированию «Git для всех» - https://stepik.org/cert/2045281
#
# Тульский государственный университет
# 2007:
# Технологический факультет
# «Технология машиностроения»

# %% [markdown]
# ## Наработки

# %% [markdown]
# Вот предложение по чек-листу для HR-специалиста, проверяющего резюме:
#
# 1. Проверить наличие основных разделов резюме:
# - Контактная информация
# - Цель
# - Ключевые навыки
# - Опыт работы
# - Образование
# - Дополнительная информация
#
# 2. Проверить, что в разделе "Цель" четко сформулирована цель кандидата и соответствие вакансии.
#
# 3. Убедиться, что в разделе "Ключевые навыки" перечислены навыки, соответствующие требованиям вакансии.
#
# 4. Проверить хронологический порядок пунктов в разделе "Опыт работы".
#
# 5. Убедиться, что в описании опыта работы указаны должностные обязанности и достижения, а не просто общие фразы.
#
# 6. Проверить наличие реальных цифр, фактов, примеров в описании опыта работы.
#
# 7. Убедиться, что уровень детализации сопоставим для разных мест работы.
#
# 8. Проверить отсутствие опечаток и грамматических ошибок.
#
# 9. Убедиться в корректности контактной информации.
#
# 10. Проверить общее визуальное восприятие документа - шрифты, выравнивание, интервалы.

# %% [markdown]
# Вот мои предложения по оптимизации разделов резюме:
#
# Цель:
# Должность: Data Scientist
# Зарплата: от X руб.
# Готов к переезду/командировкам: [указать готовность]
#
# Ключевые навыки:
# - Python (pandas, numpy, sklearn, tensorflow) - уровень upper-intermediate
# - Статистический анализ данных - уровень upper-intermediate
# - Машинное обучение (классификация, регрессия, кластеризация) - уровень upper-intermediate
# - NLP (обработка текстов, классификация текстов) - уровень intermediate
# - Визуализация данных (Matplotlib, Seaborn) - уровень upper-intermediate
# - SQL, PostgreSQL - уровень intermediate
# - Опыт работы с большими объемами данных - 1 год
#
# Опыт работы:
#
# Июль 2021 - наст. время (1 год 4 месяца)
# Data Scientist, Clovery
# - Разработал модель классификации вакансий по 20+ классам на основе RNN с точностью 85%
# - Реализовал систему извлечения структурированных данных из текста вакансий (зарплата, контакты, опыт) с F1 score 0.89
# - Обеспечил сбор данных из 15 источников с последующей выгрузкой в PostgreSQL
#
# Июль 2020 - Июль 2021 (1 год)
# Data Scientist, Моторика
# - Разработал модель классификации жестов руки на основе CNN с точностью 93%
# - Предложил использование дополнительных датчиков, что повысило точность на 5%
# - Реализовал процессинг данных от датчиков с помощью Pandas
#
# Образование:
# [подробное описание с указанием факультета, кафедры, направления подготовки]

# %% [markdown]
# Благодарю за предоставленные примеры, они помогут мне лучше понять задачу.
#
# Итак, чтобы проверить заполнение раздела "Опыт работы" в резюме, я буду следовать такому алгоритму:
#
# 1. Разделю текст раздела "Опыт работы" на отдельные блоки для каждого места работы.
#
# 2. Для каждого блока проверю:
#
# - Наличие дат в указанном формате Месяц Год - Месяц Год. Если формат не соблюден - отмечу ошибку.
#
# - Наличие названия компании. Если не указано - отмечу ошибку.
#
# - Наличие занимаемой должности. Если не указана - отмечу ошибку.
#
# - Наличие описания обязанностей и достижений. Если отсутствует - отмечу ошибку.
#
# 3. Подсчитаю процент ошибок по количеству блоков опыта работы.
#
# 4. Если процент ошибок превышает некий допустимый порог (например 20%) - сообщу, что раздел заполнен с ошибками.
#
# 5. Выдам список конкретных ошибок в разделе и рекомендации по их исправлению.
#
# Такой подход позволит методично проанализировать информацию в разделе "Опыт работы" и выявить несоответствия заданному шаблону. Готов отвечать на дополнительные вопросы и уточнять логику, если в моем подходе есть недочеты.

# %% [markdown]
# Вот вариант переписанного раздела "Образование" из предоставленного резюме:
#
# Образование
#
# Университет искусственного интеллекта, г. Москва
# 2020 г. - н.в.
# Специальность: Прикладная математика и информатика
# Специализация: Data Science
#
# Основные дисциплины:
# - Машинное обучение
# - Нейронные сети
# - Методы компьютерного зрения
#
# Пермский национальный исследовательский политехнический университет, г. Пермь
# 2014 г.
# Специальность: Прикладная математика и информатика
# Специализация: Системы автоматизированного проектирования
#
# Основные дисциплины:
# - Программирование
# - Вычислительная математика
# - Моделирование систем
#
# Дополнительное обучение:
#
# - Курс "Машинное обучение для анализа данных", Coursera (сертификат)
# - Курс "Python для анализа данных", Stepik (сертификат)
#
# Таким образом, раздел "Образование" переписан в соответствии с рекомендациями:
# - Добавлены города учебных заведений
# - Расширены сведения о специальностях и направлениях подготовки
# - Добавлены ключевые дисциплины
# - Выделен блок с информацией о дополнительном обучении
# - Устранены стилистические погрешности

# %% [markdown]
# Вот чек-лист для работы специалиста HR-отдела по проверке резюме:
#
# - Персональная информация: проверить наличие контактных данных (ФИО, номер телефона, email, telegram)
#
# - Желаемая должность: соответствует ли указанная должность в резюме вакансии, на которую откликается кандидат
#
# - GitHub: проверить наличие ссылки и качество представленных проектов
#
# - Навыки: соответствуют ли указанные навыки требованиям вакансии
#
# - Хакатоны: проверить наличие сертификатов, если указано участие
#
# - Опыт работы: проверить хронологический порядок, наличие дат, названий компаний, описания обязанностей и достижений
#
# - Образование: проверить наличие данных об образовании, совпадение специальности с вакансией
#
# - Дополнительная информация: проверить наличие полезных навыков и квалификаций
#
# - Общее: проверить лаконичность, читабельность, грамотность, отсутствие опечаток и стилистических ошибок

# %% [markdown]
# по предложенному тобой чек-листу проанализируй резюме кандидата и укажи конкретные замечания.
#
#
# Вот мои замечания к предоставленному резюме кандидата согласно чек-листу:
#
# - Персональная информация: присутствует в полном объеме
#
# - Желаемая должность: указана, соответствует вакансии Data Scientist
#
# - GitHub: ссылка отсутствует
#
# - Навыки: соответствуют требованиям вакансии Data Scientist
#
# - Хакатоны: указано участие в хакатоне "Humans VS AI" в марте 2023 года, но отсутствует ссылка на сертификат
#
# - Опыт работы: присутствует в хронологическом порядке с указанием дат, названий компаний, описанием обязанностей и достижений
#
# - Образование: указано высшее образование по специальности, соответствующей вакансии Data Scientist
#
# - Дополнительная информация: указаны ключевые навыки, релевантные для вакансии Data Scientist
#
# - Общее: резюме читабельное, структурированное, оформлено аккуратно, опечаток и ошибок не обнаружено
#
# Основные замечания:
#
# - Отсутствует ссылка на GitHub
# - Отсутствует ссылка на сертификат по итогам хакатона
#
# Рекомендую запросить у кандидата недостающую информацию. В целом резюме хорошо структурировано и соответствует требованиям вакансии Data Scientist.

# %% [markdown]
# предложи, как оптимально изменить текст этих разделов резюме с учетом замечаний. Если не хватает какой-то информации в резюме соискателя, то дай подробный образец для заполнения этого раздела.
#
# Вот мои предложения по оптимизации текста резюме:
#
# GitHub:
# Добавить ссылку на GitHub профиль. Например:
#
# GitHub: https://github.com/vladimirvlasov
#
# При наличии релевантных проектов в GitHub, добавить их краткое описание в раздел "Опыт работы", например:
#
# - Разработал и опубликовал в GitHub репозиторий с проектом по классификации текстов с использованием моделей машинного обучения (ссылка на репозиторий)
#
# Хакатоны:
# Добавить ссылку на сертификат участника хакатона "Humans VS AI". Например:
#
# - Хакатон "Humans VS AI", март 2023 - сертификат участника (ссылка)
#
# Если в хакатоне был конкретный проект, то добавить краткое описание, как и для опыта работы.
#
# Опыт работы:
# Добавить больше цифр и фактов, подтверждающих эффективность работы. Например:
#
# - Создал классификатор жестов, который показал точность 98% на тестовых данных
#
# - Агрегатор вакансий позволил увеличить число обрабатываемых вакансий на 35% по сравнению с предыдущим решением
#
# Также можно добавить используемые инструменты и технологии, если их не хватает в разделе "Ключевые навыки".
#
# В целом резюме хорошее, требуется лишь добавить некоторые детали, чтобы сделать его более информативным для HR.

# %% [markdown]
# оцени в процентах насколько каждый раздел резюме соответствует требованиям чек-листу. Если возникнут сложности с оценкой, то обращайся к документу с требованиями по заполнению резюме. мне нужен ответ в виде:
#
# "Раздел резюме: соответствует на Х процентов".
#
# Вот оценка в процентах соответствия разделов резюме чек-листу:
#
# Персональная информация: соответствует на 100%
#
# Желаемая должность: соответствует на 100%
#
# GitHub: соответствует на 0% (ссылка отсутствует)
#
# Навыки: соответствует на 100%
#
# Хакатоны: соответствует на 70% (отсутствует ссылка на сертификат)
#
# Опыт работы: соответствует на 90% (можно добавить метрики и цифры)
#
# Образование: соответствует на 100%
#
# Дополнительная информация: соответствует на 100%
#
# Общее: соответствует на 90% (небольшие недочеты устранимы)
#
# Таким образом, наиболее проблемные разделы - GitHub и Хакатоны. Рекомендую запросить у соискателя дополнительную информацию и добавить ее в резюме для повышения процента соответствия. В целом резюме хорошее и в большей степени соответствует предъявляемым требованиям.

# %% [markdown]
# перепиши раздел резюме опыт работы в соответствии с требованиями к составлению резюме. Используй только текст из резюме соискателя. Исправь логические, стилистические ошибки в тексте раздела резюме
#
#
# Вот вариант переписанного раздела "Опыт работы" из предоставленного резюме:
#
# Опыт работы
#
# Университет искусственного интеллекта, Москва
# Август 2023 - настоящее время
# Должность: Python-разработчик
#
# - Разработал сайт-конструктор резюме для студентов и выпускников УИИ с использованием Python, ChatGPT и LangChain
# - Создал базу знаний на основе HR-документов для обучения ChatGPT оформлению резюме
# - Разработал алгоритм проверки заполнения разделов резюме на соответствие требованиям HR
# - В результате был создан удобный инструмент для составления профессиональных резюме
#
# Хакатон "Humans VS AI", Москва
# Март 2023 - 1 месяц
# Должность: Data Scientist
#
# - Разрабатывал алгоритм классификации текстов, написанных человеком или ИИ
# - Применил библиотеки NLTK, spaCy, HuggingFace для повышения качества классификации
# - Достиг точности классификации 96% на тестовых данных
#
# Компания "Моторика", Пермь
# Июль 2022 - Октябрь 2022
# Должность: Data Scientist
#
# - Разработал модели классификации жестов руки на основе глубокого обучения
# - Созданный классификатор показал точность 98% на тестовых данных
# - Предложил использование дополнительных датчиков для повышения качества распознавания
#
# Компания "Clovery", Пермь
# Июль 2021 - Октябрь 2021
# Должность: Data Scientist
#
# - Разработал алгоритмы для классификации и извлечения данных из вакансий
# - Агрегатор вакансий позволил увеличить число обрабатываемых вакансий на 35%
# - Реализовал классификацию вакансий на 20+ профессий с использованием методов машинного обучения

# %%
Главная гипотеза

# %% [markdown]
# Вот пример того, как можно обучить ChatGPT на данных для проверки резюме:
#
# Пример промпта:
#
# "Я хочу научить тебя проверять резюме на соответствие требованиям к заполнению разделов.
#
# Вот шаблон требований к разделу "Опыт работы":
#
# - указываются даты работы в компании в формате Месяц Год - Месяц Год
# - указывается название компании
# - указывается занимаемая должность
# - описываются обязанности и достижения на данной позиции
#
# А вот пример правильно заполненного раздела:
#
# Опыт работы
# Компания "DataCorp", г. Москва
# Июнь 2019 - Июль 2022
# Должность: Ведущий аналитик данных
# - Разработка и внедрение систем машинного обучения для анализа потребительского поведения
# - Повышение точности модели предсказания оттока клиентов на 5%
#
# А вот пример с ошибкой:
#
# Опыт работы
# Компания "DataCorp", Москва, июнь 2019 - июль 2022
# Ведущий аналитик данных
# Разработка внедрение моделей машинного обучения
#
# Пожалуйста, проанализируй приведенные примеры и объясни, как ты будешь проверять заполнение раздела "Опыт работы" в резюме."

# %% [markdown]
# Благодарю за предоставленные примеры, они помогут мне лучше понять задачу.
#
# Итак, чтобы проверить заполнение раздела "Опыт работы" в резюме, я буду следовать такому алгоритму:
#
# 1. Разделю текст раздела "Опыт работы" на отдельные блоки для каждого места работы.
#
# 2. Для каждого блока проверю:
#
# - Наличие дат в указанном формате Месяц Год - Месяц Год. Если формат не соблюден - отмечу ошибку.
#
# - Наличие названия компании. Если не указано - отмечу ошибку.
#
# - Наличие занимаемой должности. Если не указана - отмечу ошибку.
#
# - Наличие описания обязанностей и достижений. Если отсутствует - отмечу ошибку.
#
# 3. Подсчитаю процент ошибок по количеству блоков опыта работы.
#
# 4. Если процент ошибок превышает некий допустимый порог (например 20%) - сообщу, что раздел заполнен с ошибками.
#
# 5. Выдам список конкретных ошибок в разделе и рекомендации по их исправлению.
#
# Такой подход позволит методично проанализировать информацию в разделе "Опыт работы" и выявить несоответствия заданному шаблону. Готов отвечать на дополнительные вопросы и уточнять логику, если в моем подходе есть недочеты.

# %%
ЦЕЛЬ
О СЕБЕ == саммари
НАВЫКИ
СОЗДАННЫЕ НС
ПРОФЕССИОНАЛЬНАЯ ДЕЯТЕЛЬНОСТЬ == опыт работы
ОБРАЗОВАНИЕ

составь мне шаблон требований к разделу "Опыт работы":
Беру текст целей из базы знаний, примеры целей, составляю чек-лист

# %% [markdown]
# # PDF to text

# %% [markdown]
# ## PDF python

# %%
# !sudo apt install build-essential libpoppler-cpp-dev pkg-config python3-dev

# %%
# !pip install pdftotext

# %%
import glob


for path in glob.iglob('good/*'):
    print(path)
# Out:
# good/хорошийпримерМатвеев Константин.pdf
# good/хорошийпримерПервушин Илья.pdf
# good/хорошийпримерДеген Юлия.pdf
# good/хорошийпримерНиязбек Уулу Эркинбек.pdf
# good/хорошийпримерКорнилин Владислав ML.pdf

# %%
import pdftotext

# Load your PDF
with open("guide.pdf", "rb") as f:
    pdf = pdftotext.PDF(f)

    # # If it's password-protected
    # with open("secure.pdf", "rb") as f:
    #     pdf = pdftotext.PDF(f, "secret")

    # How many pages?
    print(len(pdf))

    # # Iterate over all the pages
    # for page in pdf:
    #     print(page)

    # # Read some individual pages
    # print(pdf[0])
    # print(pdf[1])

    # Read all the text into one string
    print("\n\n".join(pdf))
# Out:
# 6

# %%
for path in glob.iglob('good/*'):
    with open(path, "rb") as f:
        pdf = pdftotext.PDF(f)

    print(len(pdf))

    print("\n\n".join(pdf))


    print("\n\n","=="*10,"\n\n")

# %% [markdown]
# ## Примеры хороших резюме

# %%
КОНСТАНТИН МАТВЕЕВ
DATA SCIENTIST


О СЕБЕ

Многопрофильный IT специалист с опытом работы в анализе данных и программировании на языке Python.
Изучил алгоритмы машинного обучения, включая регрессию, классификацию и кластеризацию. Успешно
работал в команде, проявляя целеустремленность и ответственность. Ищу возможность применить свой
опыт и навыки в сфере Data Science.


НАВЫКИ

Pymorphy2
Python
NumPy
Pandas
Matplotlib
Seaborn
Librosa
Gensim
Scikit-learn
SciPy
Attention
Transformers
Q-learning
Keras
Pytorch
Tensorflow
Text2Image
GPT
Seq-2-Seq
CycleGAN
YOLOv5
PIL
REINFORCE
CGAN
WGAN
Pix2Pix
TTS
STT
DeepSpeechs
Сv2
TimeSeries
CTCloss
TextRecognitionDataGenerator
EasyOCR
Tesseract
VGG
ResNet
Inception
Unittest Pytest Json
DjangoRESTFramework KerasTuner
ImageDataGenerator ООП Git
Requests
Docker
SQL
HTML/CSS
Bootstrap
Flask


ОПЫТ РАБОТЫ

Стажер Data Science
ГК «ОТР» | 02. 2023 – по настоящее время
Проект CV (распознавание данных в документах: общегражданский паспорт, СНИЛС, ИНН)
Разработка механизма автоматического поворота документов
Разметка данных
Анализ данных/поиск материалов
Формирование синтетических данных
Распознавание и классификация данных
Стек: Keras, PyTorch, Tensorflow, Pandas, Numpy, Sklearn, Matplotlib, CTC loss, TextRecognitionDataGenerator,
EasyOCR, Tesseract, YOLOv5, ViT, ImageDataGenerator, Cv2, PIL, RuBERT, KenLM, jamspell, KerasTuner

Региональный технический директор / Директор по информационным
технологиям и автоматизации / Руководитель проекта / Управляющий
директор системного интегратора
Proget Software / МУП Водоканал / Интерпроком / Производственный холдинг / MFMIntegration
08. 2013 – по настоящее время
Задачи:
Внедрение и сопровождение систем класса EMM/MDM
Внедрение и сопровождение систем класса ITSM
Внедрение и сопровождение систем мониторинга зонтичного типа
Внедрение и сопровождение систем управления рабочими станциями
Внедрение ERP, CRM и систем коллективной работы
Оптимизация ИТ стратегии согласно потребностям бизнеса
Импортозамещение программных и аппаратных комплексов
Разработка сервисно-ресурсной модели, матрицы ответственности, модели взаимодействия, SLA, KPI
Формирование и актуализация портфеля решений, генерация идей по новым продуктам
Формирование и реализация коммерческой и маркетинговой стратегии предприятия
Формирование технических решений, расширение каталога услуг
Активное применение современных методологий управления проектами (Agile, Scrum)
Фасилитация собственной команды и команды заказчика в роли Scrum Master
Результаты:
Разработал roadmap создания и развития информационных сервисов МУП Водоканал для потребителей на 5 лет
Интегрировал цех автоматизации (КИПиА) в структуру дирекции ИТ
Оптимизировал ФОТ на 22%
Выполнил автоматизацию автотранспортного предприятия
Подготовил проект миграции СЭД на новую платформу
Спроектировал и ввёл в опытную эксплуатацию систему коллективной работы и управления задачами
Реализовал переход на систему управлением предприятия (1С: ERP)


ОБРАЗОВАНИЕ

2022
Университет Искусственного Интеллекта Terra AI
Data Science, нейронные сети, машинное обучение и искусственный интеллект
Дипломный проект: Предсказание тренда на акции
Разметка тренда
Тестирование различных гипотез
Выбор архитектуры нейросети
Оптимизация
Подбор гиперпараметров
Достижение максимальной точности
Достижение: Достигнута точность предсказания тренда акций 96%
Ссылка на презентацию: https://docs.google.com/presentation/d/1eAz3CaVBGJZauHHPbE1KUp81GDOZ2G1DCJU8JE8vQo/edit#slide=id.gd8aed03899_0_1070

2021
SkillFactory
Data Scientist

2020
SkillFactory
Python-разработчик

2012
Московский финансово-юридический университет
Факультет Экономики и Права
Юрист

1997
Московский государственный технический университет им. Н.Э. Баумана, Москва
Факультет робототехники и комплексной автоматизации
Подъемно-транспортные, строительные, дорожные машины и оборудование

1991
Московский учебно-производственный центр вычислительной техники
Программист


РЕАЛИЗОВАННЫЕ ПРОЕКТЫ

ПАО Аэрофлот - Российские авиалинии
- Система Мониторинга Производственных Систем
- Сервис-Деск и управление рабочими станциями Банк Хоум Кредит
- Миграция системы Сервис-Деск на новую платформу, интеграция с информационными системами банка
- Портал самообслуживания для сотрудников банка Райффайзенбанк
- Портал самообслуживания для сотрудников банка X5 Retail Group
- Поддержка системы Сервис-Деск и интеграция с информационными системами Тандер (Магнит)
- Поддержка системы Сервис-Деск и интеграция с информационными системами


СЕРТИФИКАТЫ

Certified Novell Administrator
Certified Novell Engineer
Master Certified Novell Engineer
Microsoft Certified System Engineer
Comptia IT Project +


СОЗДАННЫЕ НЕЙРОННЫЕ СЕТИ

НС для предсказания трафика с сайта компании
НС для сегментации по фотографии стройки, самолётов
НС для обнаружения самолёта и других объектов на картинке
НС для классификации автомобилей
НС для классификации объектов cifar10
НС для классификации изображений на базе MNIST
Генетический алгоритм для посадки корабля
Генетический алгоритм для оптимального распределения грузов по поездам
НС для классификации текстов писателей
НС для предсказания цены/тренда акций компании


КОНТАКТЫ

+7(926)030-37-05
konstantin.matveyev@gmail.com
@costamatveev
г. Москва


 ====================

ИЛЬЯ Владимирович
Разработчик ChatGPT


О СЕБЕ

Специалист в области искусственного интеллекта с опытом применения больших
языковых моделей (LLM) и интеграции нейронных сетей в приложения. Имею 3-х
летний опыт аналитики и интерпретации больших данных, а также опыт защиты
digital-проектов на питч-сессиях. Ранее работал в сфере маркетинга, рекламы и
PR, по первому образованию преподаватель
https://github.com/ml-data-science/


КОНТАКТЫ

8 (926) 399-39-92
@curtex
artwiser@yandex.ru


НАВЫКИ

Python, Pandas, Dask, NumPy, Matplotlib,
Seaborn, Scikit-learn, Keras, Tensorflow, GPT
(языковое моделирование), TTS/STT, Streamlit,
Django/Flask/FastAPI, linux, json, Requests,
HTML/CSS, SQL, ORM, Docker, PHP, ООП, Git,
JupiterLab, Colab, Visual Studio Code


ХАКАТОНЫ

11.2020, Data Science чемпионат
IV место в высшей лиге, Сертификат
❖ Роли: Руководитель проекта и методист
❖ Трек с NLP-задачей "Развитие сервиса персональных траекторий"

10.2020, Лидеры цифровой трансформации
VI место, Сертификат
❖ Роли в команде: руководитель проекта, data scientist и методист.
❖ Трек "Легкий старт", обработано более 3000 заявок и одобрено к участию 357 команд


ПРОФЕССИОНАЛЬНЫЙ ОПЫТ

Аналитик по обработке больших данных, 01.2021 – по настоящее время
ОФД «Первый ОФД», Москва, https://продажи.рф/, https://www.1-ofd.ru/
❖ Разработал приложение с применением ChatGPT на данных о компании
❖ Разработал сервисы по интерпретации продаж, сравнению периодов продаж,
поиску регулярной цены, промо-цены и аутоффстока, отбору чековых
наименований, очистки категорий и брендов, проверке качества данных и тд.
❖ Реализовал ad_hoc проекты для клиентов, осуществлял координацию с
отделом продаж для эффективной работы с данными

Руководитель digital-проектов, 08.2013 – 12.2020
ООО Артвайзер, https://www.artwiser.ru/
❖ Организовывал интернет-продажи билетов, прогнозировал продажи с
динамическим ценообразованием, занимался продвижением сайта, руководил
командами разработчиков и дизайнеров (3-5 человек)

Руководитель проектов Департамента маркетинга и PR, 11.2011 – 08.2013
NCC Group (ныне Global Ports, https://www.globalports.com/ru/)
❖ Организовывал маркетинговые программы, участие предприятий холдинга в
международных выставках и конференциях, работал со СМИ

Руководитель проектов Департамента рекламы, 03.2009 – 10.2011
Банк ЗЕНИТ, https://www.zenit.ru/
❖ Участвовал в открытии новых офисов банковской сети, занимался
разработкой сайта для банковской группы, годовых отчетов, организовывал
рекламные кампании и коммуникации с VIP-клиентами

Арт-директор, 01.2008 – 03.2009
АНО Мастер-класс https://masterclass.ru/
❖ Организовывал комплексные мероприятия в городах России и в странах СНГ


КУРСЫ

2023, Университет Искусственного Интеллекта
❖ ChatGPT Professional
❖ Дообучение ChatGPT на собственной базе
❖ Интеграция в Production,
❖ Телеграм-бот и Android-приложение с
нейронной сетью

2019, Скилбокс
❖ Data Science

2019, Нетология
❖ Управление интернет-бизнесом
❖ Email-маркетинг в CRM-системах
❖ Контекстная реклама
❖ SEO


ОБРАЗОВАНИЕ

2023, Университет Искусственного Интеллекта
Нейронные сети, машинное обучение и искусственный интеллект

2013, Московская Торгово-промышленная палата
Методология PMI, информационные системы управления проектами, Управление
маркетингом и продажами, создание бренда

2013, Национальный исследовательский университет "Высшая школа экономики"
Высшая школа маркетинга и развития бизнеса, Международная программа НИМА

2009, Московский государственный университет им. М.В. Ломоносова
Факультет журналистики, Реклама и PR

2008, Московская государственная консерватория им. П.И. Чайковского
Преподаватель


 ====================


Юлия Деген
DATA SCIENTIST


О СЕБЕ

Имею опыт работы с анализом данных, и внедрением приложений для мобильных платформ и
виртуальной реальности. Склонна к нахождению простых решений для сложных задач. Люблю
самостоятельно решать задачи, в том числе нерешаемые. Также имею опыт работы со
вспомогательным софтом и расширениями для приложений.
Juvisuel · GitHub


НАВЫКИ

Python
NumPy
Pandas
Matplotlib
Pymorphy2
Keras
Tensorflow
NLP
Seq-2-Seq
REINFORCE
GAN
ООП
Git
Unittest
Pytest
Json
Requests
SQL
linux
Docker


КОНТАКТЫ

+7 (926) 639 - 99 - 37
juvisuel@gmail.com
@hirokama


ПРОФЕССИОНАЛЬНЫЙ ОПЫТ

ООО «Хирокама» | 06.2017 – по настоящее время
Генеральный директор
Разработала собственную модель того, как работает бессознательность
человека. На основании данной модели создавала проекты под заказ, решая
задачи заказчиков
Достижения:
- Выявляла, чем проекты были по-настоящему уникальны, благодаря брендингу
- Переводила эмоциональный язык на человеческий при создании нейминга
- Продвигала проекты, используя различные методы и инструменты для
привлечения внимания к ним
- Успешно выводила проекты на Бумстартере
- Решила задачу масштабирования и автоматизации данной технологии
- Создала и протестировала около 50 продуктов

Фриланс / частная практика | 06.2011 – по настоящее время
Проект:
Since writer – собственный проект
Задачи:
- Создание IT решение на базе собственной технологии анализа текстов: разбор
на различные уровни смысла, выявление подтекста
Достиженния:
- Создала блок анализа
- Написала сервис аналитики постов для VK
- Стадия MVP
- Проект приносит продажи
Стек: Python, Pymorphy3, Pandas, Numpy
Ссылка: https://hirokama.ru/translate1

Проект:
Чат-бот для Telegram «Психолог»
Задачи:
- Реализация метода выхода из схемы с проверками шагов выхода в формате чат-бота
Достижения:
- Бот работает с 07.2022 г.
Стек: Python3, Pymorphy3, Numpу
Ссылка: https://t.me/GuardSheme_assist_bot (включен с 11:00 до 19:00 по рабочим дням)

Проект:
Система машинного зрения для сервиса 3d моделей на базе Numpy
Задачи:
- Отделение объекта от фона
- Определение преобладающих цветов изображения в RGB
- Ранжирование большого объема данных под запрос по принципу близости цветового решения
Достижения:
- Создала систему, способную со скоростью 0.1 сек на запрос выдать из
библиотеки в 100 000 айтемов ранжирование по любому набору любых
заданных на входе цветов в цветовом диапазоне 16 000 000
Стек: Numpy
Проект на бэкенде сервиса, сервис готовится к запуску, но есть демо-версия
в чат-боте.Мможно запустить под запрос

ООО «Чингис», г. Москва
Сооснователь и Арт-директор
- Организация и поддержка отдела производства видео – успешно осуществила управление производством графического видеоконтента (выставка «Романовых»; «Подводная война»; «проект Украина»; «Форбс 2016»; «Агросалон» и др.)


ОБРАЗОВАНИЕ

Университет искусственного интеллекта Terra AI | 2022
«Data science, машинное обучение, нейронные сети и искусственный интеллект»
Дипломный проект: предсказание состояний изменяемых признаков слов по начальным формам для связи слов в предложения
Процесс работы:
- Чистка исходных датасетов
- Подготовка данных, создание 11 промежуточных словарей для многоуровневого оne hot
- Тестирование различных архитектур, в том числе, с помощью генетических алгоритмов,
создание нестандартной архитектуры сети
- Обучение сети, повышение качества результата
Решение: Удалось получить 99+% точности предсказания
Стек: Python, Pandas, Jupiter, Numpy, Matplotlib,Math, SciPy, Keras, Tensorflow, Pymorphy3
Ссылка на проект: https://colab.research.google.com/drive/1aHYlgbTMrFQeGnLotLhIseBZ0cw3MXJo?usp=sharing

Университет искусственного интеллекта Terra AI | 2022
«Python – Разработчик»

Могилевский государственный университет им А. А. Кулешова | 2000
Учитель русского и белорусского языка и литературы


СОЗДАННЫЕ НС

- НС для предсказания цен автомобилей с точностью более 93 процента
- НС для классификации текстов писателей
- Нейронная сеть для классификации заболеваний
- НС для сегментации текста
- НС для предсказания цены/тренда акций компании
- НС для классификации жанров музыки
- НС для выделения конкретного голоса/звука из аудио потока
- НС, генерирующая новые рукописные цифры
- НС для сегментации фотографий стройки, самолетов
- НС для обнаружения самолета и других объектов на картинке

 ====================

НИЯЗБЕК УУЛУ ЭРКИНБЕК
DATA SCIENTIST


О СЕБЕ

Работаю инженером в области искусственного интеллекта. Обладаю знаниями и умениями для работы с нейронными сетями и анализом данных. Ищу работу в сфере Data Science для продолжения своего профессионального роста.


НАВЫКИ

Python
C++
NumPy
Pandas
Matplotlib
Scikit-learn
Keras
Pytorch
Tensorflow
NLP
Seq-2-Seq
GPT
Q-learning
REINFORCE
GAN
CGAN
WGAN
TTS
STT
DeepSpeech
Object Detection
VGG
ResNet
ООП
Git
Json
Linux


ПРОФЕССИОНАЛЬНАЯ ДЕЯТЕЛЬНОСТЬ

Computer vision engineer
High school, Алтын туйун | 10.2022 - по настоящее время
- Разработал и внедрил алгоритмы распознавание лиц и синтез речи
- Применил методы глубокого обучения, включая сверточные нейронные сети
- Использовал алгоритмы обработки естественного языка (NLP) для разработки
моделей анализа настроений и систем классификации текста
- Применил обнаружения объектов в реальном времени на платформе NVIDIA Jetson
для оптимизации производительности и точности

Кыргызская национальная академия наук | 02.2019 – 01.2023
- Участвовал в разработке программных модулей на основе С++ для системы
управления роботом-манипулятором на основе Arduino, ESP32
- Внедрял принципы объектно-ориентированного программирования (ООП) для
повышения функциональности и удобства сопровождения программного
обеспечения
- Сотрудничал с инженерами по аппаратному обеспечению для интеграции
программных и аппаратных компонентов, обеспечивающих бесперебойную работу и
надежную работу
- Проводил модульное тестирование и отладку для выявления и устранения
проблем с программным обеспечением, оптимизацией общей эффективности
системы

Computer vision engineer
Ulut soft | 10.2021 - 06.2022
- Разработал и внедрил систему оценки скорости автомобиля с использованием
алгоритмов компьютерного зрения
- Разработал модели обнаружения объектов для идентификации и отслеживания
транспортных средств в видеопотоках
- Использовал методы оптического потока для оценки векторов движения
транспортных средств, что позволило точно рассчитать скорость
- Проводил эксперименты и бенчмаркинг для оценки производительности
различных алгоритмов и их тонкой настройки для получения оптимальных
результатов
- Создал конвейер данных для обработки крупномасштабных наборов видеоданных,
обеспечивающий эффективную обработку и хранение
- Сотрудничал с командой инженеров для интеграции системы оценки скорости
транспортного средства в более крупное решение для управления дорожным
движением
- Проводил полевые испытания и проверка для обеспечения точности и надежности
системы в реальных сценариях

Фриланс / частная практика
Проект:
Создал чат-бот «Уинстон» | 01.2023
Чат-бот был разработан для академии Motion Web
Ответы на вопросы студентов:
- Какие курсы можно пройти в академии
- Запрос информации о самой академии
- Ряд других вопросов
Стек: Nltk, Numpy, Json, Torch

Проект:
Заказчик ИП Иван Комаров | 12.2022
Успешно разработал программное обеспечение, которое выполняет следующие
функции:
- Функцию распознавания людей
- Функцию извлекающего константного BBOX
- Функцию определения пересечения BBOX
- Функцию, извлекающего максимума если камера распознает много объектов

Проект:
Goodini | 06.2021
Human detection
- Разработал умную камеру для виртуального Reception, для слежения за присутствием человека
Если есть человек, то активируется функция микрофона. Если нет, то ждет, пока подойдет человек
Стек: OpenCV, PyTorch, YoloV5, Numpy, Tracker, ElementTree


УЧАСТИЕ В ХАКАТОНАХ

01.2022
ISS-HACK
«Детектор огнестрельного оружия»
Ссылка на сертификат: https://drive.google.com/file/d/1nmJvIex5pzQyrtiuHjzo_5JcHhsfW1QW/view


ОБРАЗОВАНИЕ

2022 | Университет искусственного интеллекта Terra AI, г. Москва
«Data Science, нейронные сети, машинное обучение и искусственный интеллект»
Дипломный проект: Al car parking system
Описание: Данный проект предназначен для эффективного способа поиска свободных мест и
управления количеством транспортных средств, въезжающих и выезжающих в парковочных
станциях, путем обнаружения транспортного средства с помощью компьютерного зрения
(object detection или computer vision).
- Поступление данных из видео-камеры в
режиме реального времени
- Обработка ранее обученной модели
- Информирование о наличии свободных мест
Стек: OpenCV, Yolov5s, PyTorch

2022 | Университет искусственного интеллекта Terra AI, г. Москва
«Python – Разработчик»

2019 | Кыргызский Государственный Университет им. Раззакова
«Структуры данных, ООП, База данных, Проектирование»


ЗНАНАИЕ ЯЗЫКОВ

Английский язык - B2


КОНТАКТЫ

+996 550-192-252
erkinbek502@gmail.com
@ai_krypton
https://github.com/Krypton0001


 ====================


Корнилин Владислав
ML-Engineer


КОНТАКТЫ

+7 (916) 231 08-46
kvs93@mail.ru
г. Москва


О СЕБЕ

Инженер по искусственному интеллекту с опытом проектирования, тестирования и разработки приложений. Имею
опыт написания кодов и алгоритмов, а также построения сложных нейронных сетей с помощью различных программ.


НАВЫКИ:

Python
NumPy
Keras
Sklearn
Seq-2-Seq
Q-learning
CGAN
GAN
Matplotlib
SciPy
TensorFlow
Object Detection
Attention
Police Gradient
WGAN
ResNet
Seaborn
Pandas
PyTorch
NLP
Transformers
Inception
VGG
SQL


УЧАСТИЕ В ХАКАТОНАХ

5 - 17 июля 2022
Цифровой прорыв: Большой спорт для IT специалистов
Задача: Предсказания уровня заражения коронавирусом в городах, работа с подготовленными предобработанными данными


СОЗДАННЫЙ AI проект

Проект: «Предсказание психологического диагноза по симптомам»
- Проведена предобработка исходных данных
- Произведено обучение нейронной сети на основе соотнесения каждого слова к определённой категории
Результат: Получена идеальная точность в 100%
Стек: Excel, Python, Pandas, Matplotlib, Seaborn, NumPy, Keras,
Tensorflow
Ссылка: https://docs.google.com/presentation/d/1kMr6Q3iAYRVdnrkrCAsNghKl-EaMtmev/edit?usp=sharing&ouid=103952689286918434377&rtpof=true&sd=true


Созданные нейронные сети

Нейронная сеть для кластеризации базы Head Hunter
Нейронная сеть, собранная при помощи генетического алгоритма для предсказания стоимости/тренда акций
Нейронные сети для сегментации фотографий стройки, самолетов
Механизм Transformers для чат-бота переводчика
Нейронная сеть для классификации "Пассажиров автобуса" по изображению с точностью более 90 процентов
Нейронная сеть для классификации отзывов людей на автомобиль Tesla


ПРОФЕССИОНАЛЬНЫЙ ОПЫТ

Стажер Data Science
ГК «Самолет» | 02.2023 - по настоящее время
Проект: Детектирование и отслеживание людей, проходящие через КПП, а также детекция каски и жилета на них
- Изучение и корректировка готового кода на Python
- Создание, разметка базы данных
- Обучение нейронных сетей для детекции и трэкинга объектов
- Использование алгоритмов YOLO, SORT, DeepSORT, FairMOT
- Написание кода для пост-обработки данных
Результат: работающая нейронная сеть
Стек: Python, Tensorflow, Keras, PyTorch, Pandas,
Matplotlib, Seaborn, NumPy, Pyplot, OpenCV, PIL,
FairMOT

Верстальщик/контент - менеджер
ИП Булгаков Михаил Юрьевич bulgakovdigital.ru | 06.2021 – 06.2022
- Подбирал и сортировал актуальную информацию
- Взаимодействовал с дизайнерами, программистами
- Сделал рерайтинг, копирайтинг текстов
- Работал с OpenCart
- Работал над контентом сайта (Microsoft Picture Manage, Adobe Photoshop)
- Делал базовую SEO оптимизацию страниц
- Делал анализ систем аналитики
- Создавал рекомендации по доработке юзабилити на основе полученных данных
Достижения: Увеличил оборот на 45%, операционную прибыль в 1,4 раз (сайт: sk-market.ru)


ОБРАЗОВАНИЕ

2022 | Университет искусственного интеллекта, Москва
«Data science, нейронные сети, машинное обучение и искусственный интеллект»
Сертификат: https://cloud.mail.ru/public/6xGQ/MXorPHUah

2017 | Московский государственный университет им. М.В. Ломоносова, г. Москва
Психология, ПсихологияСМИ и ПР, магистр


КУРСЫ

2022 | Skill Factory
«Machine Learning и Deep Learning»


ЗНАНИЕ ЯЗЫКОВ

Английский - С1

# %% [markdown]
# ## Ещё примеры образцов резюме

# %%
ИВАН ИВАНОВИЧ
Data Scientist
https://github.com/...


О СЕБЕ

Начинающий специалист в области Data Science с желанием развиваться в сфере искусственного интеллекта.
Мои амбиции и целеустремленность помогут мне достичь успеха в этой увлекательной и стремительно развивающейся сфере. Готова взяться за любые задачи и
направления работы, чтобы расширить свои знания и навыки.


НАВЫКИ

Python
NumPy
Pandas
Matplotlib
Seq-2-Seq
GPT
GAN
Requests
Docker
FastAPI


СОЗДАННЫЕ НС

- НС, собранная при помощи генетического алгоритма для предсказания типа поведения человека
- НС, собранная при помощи AutoML для предсказания типа поведения человека
- НС для сегментации фотографий трещин в геологической скважине
- НС для классификации типа поведения человека
- Генетический алгоритм для оптимального распределения грузов по поездам
- НС для классификации текстов писателей
- НС для сегментации фотографий самолетов
- НС для классификации "Пассажиров автобуса" по изображению


ПРОФЕССИОНАЛЬНАЯ ДЕЯТЕЛЬНОСТЬ

- Разработчик AI | 05.2023 – по настоящее время
Российская академия наук
Название проекта: Разработка нейронной сети для обработки данных
горного эндоскопа, распознавание трещин в горном массиве

- Разработчик telegramBot для Prodaction | 02.2023 – 05.2023
ПАО «Ростелеком»
Название проекта: Семантическая классификация деревьев

- Создание telegramBot, который на вход принимает ссылку на файл с
облаком точек и возвращает предсказание процентного содержания
пород деревьев
Результат: Разработан telegramBot
Стек: Python, TelegramBot

Фриланс / частная практика | 2022
Название проекта: Бот-коуч
Принимает вопросы на философские темы и отвечает на основании взглядов на жизнь двух коучей
- Создание telegramBot, который использует базу знаний 2 коучей и ChatGPT
Решение:
- Собрана база знаний из постов в социальных сетях, сайте коучей и
статей коучей в Яндекс.Дзен и загружена в документ на GoogleDoc
- Код обработчика telegramBot размещен на VDS-сервере
- В telegram создан telegramBot
Стек: Python, ChatGPT, TelegramBot
Ссылка на проект: ...

- Инженер-проектировщик | 08.2013 – 10.2017
ООО "ППК", г. Первоуральск
- Разработка технической документации: разделы "Архитектурные решения",
"Конструкции металлические", "Конструкции железобетонные"
- Расчет сбора нагрузок
- Подготовка документации для государственной экспертизы
Достижения:
- Спроектировала 3 детских сада, навес для трибун стадиона, пивзавод, спортивный зал


ОБРАЗОВАНИЕ

Университет искусственного интеллекта, г. Москва | 2023
«Data Science, нейронные сети, машинное обучение и искусственный интеллект»
Дипломный проект: Классификация человека по типу поведения: одиночка или командный игрок
- Предсказание образа, который представил пользователь на основании
результатов, полученных при прохождении ассоциативного теста на
testkub.ru
- Разработка модели нейросетей, используя следующие методики:
ручной подбор гиперпараметров, балансировка датасета, AutoML,
генетический алгоритм
- Размещение в Production на телеграм-боте
Решенние: Доказано, что есть закономерность в образах, которые
представляют пользователи - их предсказание с точностью 0.69
Стек: Python, Pandas, Matplotlib, AutoML, генетический алгоритм,
TelegramBot, FastAPI
Ссылка на проект: ...

Уральский федеральный университет им. первого Президента России Б.Н. Ельцина, г. Екатеринбург | 2013
«Промышленное и гражданское строительство»
Строительный факультет, специалист

# %%
ИВАН ИВАНОВИЧ

Data Scientist
https://github.com/...


КОНТАКТЫ

+7 (000) 000 - 00 – 00
Иван Иванович.ru
@Иван Иванович
г. Москва


О СЕБЕ

Начинающий специалист в сфере искусственного интеллекта. Увлечен AI как инструментом оптимизации технологических
процессов и систематизации потоков данных в сферах строительства и производства. Cтремлюсь применять свои знания, навыки
для решения сложных задач и развиваться в своей профессиональной сфере.


НАВЫКИ

Python
NumPy
Pandas
Matplotlib
Keras
Pytorch
Tensorflow
GAN
CGAN
WGAN
GIT
Object Detection
ООП


СОЗДАННЫЕ НС

НС для классификации "Пассажиров автобуса" по изображению с точностью более 90 процентов
НС для сегментации фотографий стройки, самолетов
Генетический алгоритм для оптимального распределения грузов по поездам
НС для предсказания оценки зарплаты на базе HeadHunter
НС для кластеризации базы HeadHunter
НС, собранная при помощи генетического алгоритма для предсказания стоимости/тренда акций
НС для удаления шума
НС для определения мошеннических операций на датасете транзакций по кредитным картам
НС для классификации базы обращений граждан


ПРОФЕССИОНАЛЬНЫЙ ОПЫТ

Стажер Data Science
ПАО «КАМАЗ»
08.2022 - 01.2023
Проект: «Контроль состояние водителя. Идентификация водителя»
Задачи:
- Получение тестовых результатов от YoloV3
- Разработка блока «Распознавание сонливости, частота зевания, частота
моргания (ключевые точки на лице), микросон, отвлечение взгляда.»
- Разработка визуализации результатов посредством Matplotlib и Seaborn
Достижения:
- YoloV3 показала низкую точность распознавания в сравнении с YoloV5
- Блок распознавания состояний водителя на основе библиотек OpenCV и Dlib
показал высокое качество определения изменений состояния водителя
- Блок отвлечения водителя на основе библиотек OpenCV и Dlib показал
высокое качество обнаружения лица водителя в фронтальной проекции
- Визуализация результатов получилась информативной и помогла в анализе работы модели
Стек:
- Python, Pandas, Numpy, Matplotlib, Math, Seaborn, Keras, Tensorflow

Менеджер проекта в сфере проектирования и строительства коммерческой недвижимости
OOO «СК СОЮЗ»; ООО «Гранит»; PRIDEX Group
07.2012 – по настоящее время
- Ведение заказа с момента получения ТЗ до подписания акта выполненных работ
- Помощь в разработке технического задания
- Курирование разработки рабочей документации, координация разработчиков разделов АР, ВК, ЭОМ, ОВИК, КМ, КЖ
- Проведение оценочных расчетов и подготовка бюджета объекта
- Закупка материалов
- Подбор подрядчиков и контроль сроков и качества услуг
- Контроль за соблюдением сроков и этапности работ
- Сдача объекта службам эксплуатации Заказчика и Арендодателя


ОБРАЗОВАНИЕ

Университет искусственного интеллекта | 2023:
«Data Science, нейронные сети, машинное обучение и искусственный интеллект»
Дипломный проект: «Определение сорной растительности в сельскохозяйственных
культурах»
- Сбор базы
- Подготовка и обработка базы
- Разметка и аугментация данных перед моделированием
- Обучение YoloV7, анализ обученных моделей
Решенные задачи: Получилась модель, удовлетворительная по заданным
заказчиком критериям качества предсказания
Стек: Python, Pandas, Numpy, Matplotlib, Math, Seaborn, Keras, Tensorflow
Ссылка на проект: ...

Stepic
«Поколение Python» курс для начинающих | 2022
«Поколение Python» курс для продвинутых |2023
«Поколение Python» контесты по программированию | 2023
«Git для всех» - https://stepik.org/cert/2045281 | 2023

Тульский государственный университет | 2007
Технологический факультет
«Технология машиностроения»

# %% [markdown]
# ## Плохие резюме

# %%
for path in glob.iglob('bad/*'):
    with open(path, "rb") as f:
        pdf = pdftotext.PDF(f)

    print(len(pdf))

    print("\n\n".join(pdf))


    print("\n\n","=="*10,"\n\n")

# %%
ФАТЕЕВА КРИСТИНА


ОПЫТ

07.2021 – 04.2023
Специалист Управления Клиническими Исследованиями (Младший Менеджер Проекта, международные команды)
GlaxoSmithKline, Варшава, Польша
Участие одновременно в 3 разных проектах (матричная модель
организации). Тесная работа со старшим менеджером по проекту и другими
членами команды (включая представителей поставщиков/vendor companies).
Подготовка и управление проектной и исследовательской документацией, управление
рисками, планирование проекта и управление этапами, управление поставщиками, анализ показателей команды,
организация и проведение встреч внутри команды и с поставщиками, наставник для стажеров, помощник по адаптации
для новых (в том числе иностранных) сотрудников. Повседневная деятельность с использованием многочисленных систем,
связанных с проектами в клинических исследованиях, таких как Veeva eTMF, CTMS, eDC и системы Quality Suit и т. д.

Стажер, Менеджер Данных (клинические исследования, международные команды)
GlaxoSmithKline, Варшава, Польша
Помощь старшим менеджерам группы в управлении данными
пациентов клинических исследований. Управление документацией
исследования, проведение UAT сервисов после внесения
изменений в систему. Улучшение существующих процессов для
повышения эффективности работы команды.

10.2020 – 05.2021
Менеджер проекта/CEO стартапа
Собственный ИТ продукт, Варшава, Польша
Оценка идеи, управление командой по созданию MVP (Trello),
управление рисками, исследование рынка, работа с
потенциальными конечными пользователями, исследование их
потребностей и потенциальных решений, создание концепции
UX/UI (Adobe XD), поиск и работа с инвесторами.

10.2016 – 02.2019
Младший научный сотрудник
Факультет Химии, Варшавский Политехнический Университет
Анализ литературы, генерация идей, планирование пути
исследований и управление сроками, планирование физических
экспериментов (органический синтез), проведение реакций,
анализ продуктов и интерпретация результатов. Подготовка
материалов к научным конференциям, публикациям, заявкам на
регистрацию патентов.


Образование

02.2020 – 12.2021
Магистр
Факультет Химии, Варшавский Политехнический Университет
Химическая биотехнология лекарств и косметики
Стипендия Министерства Науки и Высшего Образования Польши
для студентов с выдающимися достижениями в области науки
2020/2021

10.2015 – 02.2019
Бакалавриат
Факультет Химии, Варшавский Политехнический Университет
Биотехнология


Языки

(указаны картинки флагов стран)


Контактные данные

+7 952 117 49 09
k.d.fateyeva@gmail.com
linkedin.com/in/kfateyeva
Калининград


Дополнительные навыки

Креативное решение проблем
Управление документацией
Аналитические способности
Управление проектами
Управление рисками
Менторство

 ====================

РОГОЖИН Михаил Валерьевич

С 2020 года разработчик в сфере искусственного интеллекта (со специализацией на компьютерное зрение)

Таблица навыков:
https://docs.google.com/spreadsheets/d/1YMYX3uaGsDL40tHKr7Pg8S5yYQZBRdsoyFiIdkad_dQ/edit?usp=sharing


КОНТАКТЫ

Телефон +79787704160, e-mail: for.shild@yandex.ru


ОБРАЗОВАНИЕ

В 2002 году защитил кандидатскую диссертацию на базе Института проблем
моделирования в энергетике им. Г.С.Пухова, г.Киев.
Кандидат технических наук по специальности: «Автоматизированные системы
управления и современные информационные технологии».

2020 год. Второе высшее образование по специальности: разработчик систем с
использованием искусственного интеллекта (AI). Московский Университет
искусственного интеллекта. Дипломная работа по теме: «Идентификация
неизвестного голоса в сравнении с одним или несколькими образцами».

2021 год. Прошел обучение в PyImageSearch University (Full Access Plan) по программе “Компьютерное зрение”.


НАВЫКИ

Мои навыки разработчика базируются на самообразовании и опыте, полученном во
время стажировок, работы в open-source проекте I CANN и работе в стартапах.


ОПЫТ РАЗРАБОТКИ

По программе стажировки «Медицина», разработал модель предварительной
классификации заболеваний ЖКТ по тексту жалоб пациента. В работе использовал
разные архитектуры NLP, такие как Word2vec, seq2seq, ULMFiT и др. Также имею
опыт работы с популярными библиотеками NLTK, Pymorphy2, Gensim.

Во время стажировки в программе BCI (нейрокомпьютерный интерфейс на основе
сигналов головного мозга человека) освоил работу с сигналами, как в варианте
обработки «сырых» EEG сигналов с использованием 1d сверточных сетей, так и при
работе со спектром в 2d формате обработки изображений.

В проекте I CANN (в статусе junior developer Python) разрабатывал встроенную
ML модель нейронной сети под табличные данные с собственным REST API
(Django). Работа в проекте позволила адаптироваться в Python OOP,
использовании облачных сервисов AWS (EC2, S3, Lambda).

В 2022 году работал в косметологическом проекте, на позиции мидл разработчика
CV. Разработал модель детекции, выравнивания лица человека и систему
сравнительного измерения основных параметров лица в интересах пластической
хирургии. В ходе проекта получил навыки доведения проектов до вывода в продакшн
с помощью точки доступа на базе FastAPI, набора докер-контейнеров с выводом на
облачный сервер заказчика.

В стартапе по анализу исходного кода смарт-контракта (BSC) работал на позиции
team leader. На основе сиамской модели создал приложение для сравнения текста
эталонного контракта с исследуемым и развернул его в микросервис Flask на
отдельном облачном сервере с доступом по REST API.

Имею опыт проектирования информационных систем на уровне создания
инфологических схем. Владею языком SQL запросов на базе работы с MySQL и
PostgreSQL и языком Python на уровне ООП, а также библиотеками Numpy,
Pandas, Matplotlib, Seaborn, Scikit-Learn, Pillow.

Самостоятельно изучил функционал и применение для решения задач оптимизации
поведения агента (бота) алгоритмы Reinforcement Learning на базе нейронных
сетей и трансформеров.

Специально обучался работе с классическим OpenCV. В работе с нейросетями
одинаково владею как TensorFlow, Keras, так и PyTorch. Свободно работаю в
среде Jupyter Notebook, Pycharm, Google Colaboratory, Git, Jira, Slack.
Предварительные расчеты моделей нейросетей делаю на собственной видеокарте
Nvidia 2080ti

 ====================

РЕЗЮМЕ

АЛЕКСАНДР МАКЕЕВ
Специалист по интеграциям


ОПЫТ РАБОТЫ

2011–2023 гг.
Предприниматель
Основное направление - продажа недвижимости

2007–2011 гг.
Руководитель в ряде организаций
Продажи, IT-обслуживание, органы муниципальной власти

2000–2007 гг.
Специалист по продажам
Торговля компьютерной техникой, ITуслуги предприятиям и частным лицам


ПРОФИЛЬ

Имя
Макеев Александр Александрович
Дата рождения
06 октября 1977 г.
Адрес
Ул.Саят-Нова 44, г. Сочи
Телефон
+7 (938) 444-33-36
Электронный адрес
aamakeew@gmail.com


ОБРАЗОВАНИЕ

2023 г.
Университет Искуственного Интеллекта
Курс “ChatGPT Professional”, Курс
“Дообучение ChatGPT”

2002–2006 гг.
Таганрогский радиотехнический университет
Вычислительная техника

1993–1998 гг.
Сочинский Государственный Университет
Мировая экономика


СВЯЗЬ

Телеграм
@Alexander_O2_Sochi


НАВЫКИ

Промты
- Боты Телеграм
- Проекты на Python
- Проекты на Google Colab
- Проекты на Replit

Языки на общем уровне
- Английский
- Французский


Телефон
+7 (938) 444 333 6
Электронный адрес
aamakeew@gmail.com

 ====================

Казюлин Сергей Васильевич
Junior Data Scientist

Желаемый формат работы
удаленный формат

Желаемый уровень з/п
80 000 руб.


ТЕЛЕФОН

+375-29-231-69-32


EMAIL

sergeykazulin@hotmail.com


AI НАВЫКИ

- Обработка текстов с с помощью нейросетей
- Нейронные сети для решения задач регрессии
- Нейронные сети для прогнозирования временных рядов.
- Обработка аудиосигналов.
- Автокодировщики.
- Генетические алгоритмы
- Сегментация изображений
- Кластеризация данных
- Обучение с подкреплением
- Генерация текста
- Сегментация текста
- Обнаружение объектов
- Распознавание речи
- Реляционные Базы данных
- Алгоритмы ML
- Графические интерфейсы

- Python
- Numpy
- Pandas
- Sklearn
- XGBoost
- Catboost
- Statistic
- Tkinter
- PyQt5
- Streamlit
- Dash
- Tensorflow
- Keras
- Pytorch
- Opencv
- Yolo
- NLP
- IBM Watson
- SQL
- PostgreSQL
- Hugging Face
- Stable Diffusion
- ChatGPT


ОПЫТ И ПРОЕКТЫ

АПРЕЛЬ 2021 г. СЕНТЯБРЬ 2021 г.
Университет Искусственного Интеллекта
Обучение.
● Работы. GitHub:
https://github.com/SergeyKazulin?tab=reposito
ries
● Дипломный проект - «Определение расположенности к сердечным заболеваниям»
https://github.com/SergeyKazulin/Diploma
https://github.com/SergeyKazulin/Diploma_production


ОБРАЗОВАНИЕ РАБОТА

2021 г. - 2021 г.
Университет искусственного интеллекта
“Data Science и нейронные сети на Python”

2017 г. - 2021 г.
ООО «Эрмес-Трейд».
Генеральный директор.
Оптовая и розничная торговля продуктами питания.

1983 г.
СВВАУЛ
Командная тактическая.
Пилот вертолета.


О СЕБЕ

Легче заниматься делом, чем бездельничать. Привычка работать по 12
часов в день, столько сколько нужно для выполнения работы.

Любовь к компьтерам и интерес к программированию, новым
технологиям в общем и искусственному интелекту в частности привели
в Университет.

Наибольший интерес к восстановлению старых фото и изображений и
создание новых изображений.
Применение Искусственного интелекта в медицине.
Natural Language Preprocessing.

Думаю применение и развитие Искусственного интелекта принесет еще
много новых областей его примениния. Очень интересно узнавать и
изучать что-то новое.


ИЗУЧЕННАЯ ЛИТЕРАТУРА

Дейтел П., Дейтел Х. - "Python. Искусственный интеллект, большие данные и облачные вычисления."
Шолле Ф. - "Глубокое обучение на Python."
Шакла Н. - "Машинное обучение и TensorFlow."
Пойнтер Я. - "Программируем с PyTorch."
Ф.М. Гафаров, А.Ф. Галимянов - "Искусственные нейронные сети и их приложения."
Васильев Ю. "Обработка естественного языка. Python и Spacy на практике."
Яворски М., Зиаде Т. - "Python. Лучшие практики и инструменты. "
Хобсон Л., Ханнес Х., Коул Х. - "Обработка естественного языка в действии."
И многие другие книги по программированню...

 ====================

# %% [markdown]
# # Разработка алгоритма проверки

# %% [markdown]
# ## Шаблоны разделов

# %% [markdown]
# ### Чек-листы HR:

# %%
text = """
Вот объединенный чек-лист для составления резюме на основе данного документа:

1. Персональная информация:
   - ФИО
   - Возраст
   - Город, страна
   - Контакты (телефон, email, мессенджеры, соцсети)

2. Фото:
   - Деловой стиль
   - Хорошее качество
   - Небольшого размера
   - На усмотрение кандидата

3. Цель:
   - Желаемая должность и сфера деятельности
   - Краткое резюме опыта и навыков
   - Пример

4. Опыт работы:
   - Названия компаний и проектов
   - Периоды работы
   - Должности
   - Обязанности и достижения
   - Ключевые результаты
   - Использованные технологии и навыки
   - Пример

5. Образование:
   - Учебные заведения
   - Специальности
   - Даты обучения
   - Курсы, тренинги, сертификаты
   - Пример

6. Навыки:
   - Технические навыки
   - Языки программирования
   - Инструменты и технологии
   - Мягкие навыки
   - Пример

7. Личные качества:
   - 3-5 ключевых качеств с примерами
   - Пример

8. Языки:
   - Английский, уровень по международной шкале
   - Другие языки при наличии

9. Дополнительно:
   - Хобби, интересы
   - Готовность к командировкам
   - Портфолио, GitHub
   - Рекомендации
   - Пример

10. Проверка резюме:
    - Грамматика и ошибки
    - Соответствие требованиям

11. Оформление резюме:
    - Структурированность
    - Выделение разделов
    - 1-3 страницы
    - Формат .doc/.pdf

№17:
Вот переписанный текст в соответствии с предложенной мной структурой:

персональная_информация.txt
- Указывать все контактные данные: номер телефона, мессенджеры, email, LinkedIn и т.д.
- Можно указать "предпочтительный способ связи"

опыт_работы.txt
- Период работы
- Название компании
- Должность
- Описание проекта
- Обязанности
- Ключевые достижения
- Использованные технологии
- Ключевые навыки
- Рекомендации

навыки.txt
- Указывать только реально имеющиеся навыки
- Можно добавить портфолио или примеры кода

уровень_специалиста.txt

сильные_стороны.txt

увлечения.txt

опыт_кандидата.txt

рекомендации.txt
- Резюме 1-2 страницы
- Максимум 3 страницы
- Писать только правду
- Опыт должен быть релевантен вакансии
- Избегать шаблонных фраз

дополнительно.txt


№1
Вот предлагаемый чек-лист для заполнения резюме на основе рекомендаций из предыдущего документа:

1. Шапка резюме:
- Указаны ФИО
- Добавлена фотография
- Указаны все контактные данные (телефон, email, мессенджеры, LinkedIn)
- Отмечен предпочтительный способ связи

2. Блок "Обо мне":
- Есть краткое описание опыта, знаний, навыков
- Нет шаблонных фраз

3. Опыт работы:
- Опыт распределен от последнего к предыдущим местам работы
- Указаны название компаний, проекты, роли, обязанности, достижения, технологии
- Приведены конкретные обязанности, не общие формулировки

4. Ключевые навыки:
- Перечислены актуальные навыки и технологии
- Добавлены комментарии об уровне владения
- Есть блок "Образование"

5. Достижения:
- Приведены конкретные, измеримые, персональные и командные достижения

6. Рекомендации:
- Указаны данные лиц для рекомендаций
- Добавлены рекомендации в LinkedIn

7. Объем и формат:
- Резюме 1-3 страницы
- Сохранено в PDF и других удобных форматах

8. Прочее:
- Информация достоверная и релевантная вакансии
- Избегаются шаблоны
- Текст структурирован по разделам

№2
Вот предлагаемый чек-лист для заполнения резюме на основе данного документа:

1. Персональная информация:
- Указаны ФИО, контакты (телефон, email, мессенджеры, LinkedIn)
- Ссылки сделаны кликабельными
- Указан предпочтительный способ связи

2. Заголовок:
- Соответствует сфере и искомой должности
- Если есть несколько вариантов, сделано несколько резюме

3. Summary:
- Есть краткое введение об опыте и навыках

4. Опыт работы:
- Указан в обратном хронологическом порядке
- Указаны названия компаний, сфера деятельности, должности, проекты, обязанности, достижения, технологии
- Достижения описаны количественно

5. Образование:
- Указаны даты, вуз, специальность, степень, средний балл

6. Достижения:
- Указаны публикации, сертификаты, победы в олимпиадах

7. Технические навыки:
- Перечислены в порядке убывания сложности
- Указан уровень владения каждым навыком

8. Формат и объем:
- Объем 1-2 страницы
- Сохранено в удобных форматах (doc, pdf)


№3
Вот предлагаемый чек-лист для заполнения резюме на основе данного документа:

1. Самопрезентация:
- Указаны фото, ФИО, контакты
- Добавлены ссылки на LinkedIn и GitHub профили

2. Проекты и публикации:
- Перечислены проекты с описанием функционала, целей, технологий
- Указаны научные публикации и статьи

3. Образование:
- Указаны учебные заведения, специальности, даты обучения

4. Опыт работы:
- Сфокусирован на конкретных достижениях с цифрами
- Опыт, не относящийся к вакансии, описан кратко

5. Навыки и портфолио:
- Перечислены ключевые навыки и использованы SEO слова
- Добавлена ссылка на портфолио

6. Резюме:
- Объем 1-2 страницы
- Проверено на ошибки
- Адаптировано под конкретную вакансию

Такой чек-лист поможет составить полное резюме с упором на достижения и навыки.

№3
Вот чек-лист для заполнения резюме Data Scientist на основе данного документа:

1. Контакты
   - Фото
   - ФИО
   - Город, страна
   - Email, телефон
   - LinkedIn, GitHub

2. Цель
   - Должность

3. Проекты
   - Названия и описания
   - Использованные технологии
   - Достигнутые цели

4. Образование
   - Учебные заведения
   - Степени
   - Даты окончания

5. Опыт работы
   - Названия компаний
   - Периоды
   - Должности
   - Достижения
   - Метрики

6. Навыки
   - Технические навыки
   - Языки программирования
   - Инструменты и технологии

7. Дополнительно
   - Сертификаты
   - Портфолио
   - Участие в конференциях

8. Проверка
   - Ключевые слова
   - Грамматика
   - Актуальность
   - Краткость

9. Оформление
   - Структурированность
   - Выделение блоков
   - 1-2 страницы


№4
Вот чек-лист по заполнению резюме на основе данного документа:

1. Объем резюме:
- Не более 1-1,5 страниц
- Максимальная краткость

2. Фото:
- Качественное, однотонный фон
- Без селфи и лишних деталей

3. Цель и должность:
- Указать текущую или желаемую должность

4. Образование:
- Перечислить с указанием дат обучения
- Не указывать среднее образование

5. Опыт работы:
- Сфокусироваться на ключевом опыте
- Описать зону ответственности, задачи и достижения

6. Навыки и портфолио:
- Перечислить актуальные навыки
- Добавить ссылку на портфолио

7. Ключевые слова:
- Использовать ключевые слова по специальности

8. Оформление:
- Структурировать информацию
- Избегать воды и лишних деталей
- Проверить текст на ошибки

9. Резюме и портфолио:
- Связать резюме и портфолио между собой
- Регулярно обновлять оба документа


№4
Вот чек-лист для заполнения резюме аналитика и data scientist на основе данного документа:

1. Контакты
   - ФИО
   - Город, страна
   - Email, телефон
   - LinkedIn, GitHub, другие профильные сети

2. Цель
   - Желаемая должность

3. Образование
   - Учебные заведения
   - Специальности
   - Даты окончания
   - Курсы и сертификаты

4. Опыт работы
   - Названия компаний и проектов
   - Периоды работы
   - Должности
   - Обязанности
   - Достижения и результаты

5. Навыки
   - Языки программирования
   - Математика, статистика
   - Инструменты, технологии
   - Мягкие навыки

6. О себе
   - Личные качества
   - Уровни владения языками
   - Портфолио, проекты

7. Проверка
   - Ключевые слова
   - Грамматика и ошибки
   - Актуальность данных

8. Оформление
   - Фото
   - Структурированность
   - 1-1,5 страницы

9. Портфолио
   - Проекты по анализу данных
   - Описание целей, результатов
   - Выводы и заключения

№5
Вот извлеченная информация по каждому разделу:

1. Персональная информация:
- Указать номер телефона и email
- Добавить 2-3 дополнительных контакта (мессенджеры, соцсети)
- Проверить контакты на отсутствие ошибок

2. Опыт работы:
- Указать последнее место работы, должность, перечислить обязанности и достижения
- Для джуниоров достаточно указать кейсы и положительную характеристику от куратора
- Выделить опыт, соответствующий специализации компании

3. Навыки:
- Python, математика, SQL, C/C++, R, JavaScript, Django
- Машинное обучение, нейросети, Docker, Apache Spark, Arima, Garch

4. Сильные стороны:
- Наблюдательность, работоспособность, терпеливость

5. Увлечения:
- Указать 2-3 увлечения разной направленности

6. Опыт кандидата:
- Для джуниоров достаточно проектов и кейсов
- Для мидлов и синьоров - конкретный опыт и достижения

7. Уровень специалиста:
- Джуниор - проекты, кейсы, образование
- Мидл - 1-3 года опыта работы, кейсы
- Синьор - 3+ лет опыта, конкретные проекты и достижения

8. Рекомендации:
- Использовать краткие формулировки на 1 странице
- Создать четкую структуру с разделением на блоки
- Избегать профессионального сленга и "воды"
- Указывать только правдивую информацию

9. Дополнительно:
- Отправлять резюме в pdf
- Разместить резюме на специализированных ресурсах


№6
Вот чек-лист по основным разделам резюме:

Раздел "Контакты"

Указать ФИО
Добавить актуальные контакты (телефон, email)
Проверить контакты на корректность
Раздел "Цель"

Кратко сформулировать цель поиска работы
Указать должность и сферу деятельности
Раздел "Ключевые навыки"

Перечислить 5-7 ключевых навыков и технологий
Выделить навыки в соответствии с целью поиска
Раздел "Опыт работы"

Перечислить места работы в обратном хронологическом порядке
Указать даты, должности, обязанности и достижения
Раздел "Образование"

Перечислить учебные заведения и специальности
Указать даты обучения и полученные степени/дипломы
Раздел "Дополнительно"

Добавить курсы, сертификаты, портфолио, ссылки на профиль и т.д.
Раздел "Личные качества"

Отметить 3-5 ключевых личных качеств
Заключение:

Проверить резюме на отсутствие ошибок
Сохранить в PDF и отправить с сопроводительным письмом


№6
Вот чек-лист для составления резюме программиста на основе данного документа:

1. Контакты
   - Имя, фамилия
   - Город, страна
   - Email, телефон
   - Ссылка на LinkedIn и GitHub

2. Цель
   - Желаемая должность и специализация

3. Ключевые навыки
   - 5-10 навыков и технологий
   - Без указания лет опыта

4. Опыт работы
   - Названия компаний и проектов
   - Периоды работы
   - Должности
   - Ключевые достижения
   - Использованные технологии

5. Образование
   - ВУЗы и факультеты
   - Профильные курсы

6. Языки
   - Английский и другие
   - Уровни владения

7. About
   - Личные качества
   - Хобби и интересы

8. Проверка
   - Грамматика и орфография
   - Актуальность контактов

9. Оформление
   - Читабельность
   - Структурированность
   - 1-2 страницы

№7
Вот чек-лист по основным разделам резюме на основе предоставленного документа:

Контакты:
- Указать ФИО, город, телефон, email
- Добавить ссылки на профили в соцсетях и портфолио
- Проверить контакты на корректность

Цель:
- Указать желаемую должность и сферу деятельности

Ключевые навыки:
- Перечислить 5-7 ключевых технических навыков
- Указать уровень владения каждым навыком

Опыт работы:
- Перечислить места работы в обратном порядке
- Указать даты, должности, обязанности, достижения

Образование:
- Указать учебные заведения, специальности, годы учебы

Дополнительно:
- Добавить курсы, сертификаты, ссылки на работы

Личные качества:
- Отметить 3-5 ключевых личных качеств

Языки:
- Указать уровень владения языками

Доп. информация:
- Добавить интересы, хобби, особенности

Заключение:
- Проверить резюме на ошибки, сохранить в PDF

№8
Вот чек-лист по основным разделам резюме для последнего предоставленного документа:

Контакты:
- Указать имя, возраст, город, телефон, email
- Добавить ссылки на профили в социальных сетях

Фото:
- Включить профессиональную улыбающуюся фотографию
- Избегать неформальных, групповых фото

Резюме:
- Кратко описать квалификацию и цели
- Использовать сильный язык, цифры, факты
- Персонализировать под конкретную вакансию

Опыт работы:
- Перечислить в обратном хронологическом порядке
- Указать названия компаний, должности, обязанности
- Описать достижения, результаты, технологии

Образование:
- Перечислить учебные заведения в обратном порядке
- Указать специальности, степени, годы обучения
- Добавить полученные награды и стипендии

Навыки:
- Перечислить актуальные технические навыки
- Указать уровень владения языками
- Добавить soft skills и личные качества

Языки:
- Указать уровень владения языками

Дополнительно:
- Добавить хобби, интересы

Заключение:
- Проверить резюме на ошибки, сохранить в PDF


№9

Вот чек-лист заполнения резюме на основе предоставленного документа:

1. Персональная информация
   - ФИО
   - Контакты (телефон, email, город)
   - Дата рождения
   - (Фото - опционально)

2. Опыт работы
   - Названия компаний
   - Даты работы
   - Должности
   - Обязанности и достижения (адаптировать под вакансию)
   - Используемые технологии и инструменты

3. Навыки
   - Технические навыки (языки, фреймворки, инструменты)
   - Уровни владения технологиями
   - Мягкие навыки (коммуникация, лидерство и т.д.)

4. Образование
   - Названия учебных заведений
   - Специальности
   - Даты обучения
   - Достижения (дипломы, награды)

5. Дополнительно
   - Личные качества
   - Увлечения и хобби
   - Рекомендации
   - Цель в карьере
   - Желаемая должность и зарплата

6. Прочее
   - Проверить грамматику и орфографию
   - Соблюдать лаконичность
   - Адаптировать под вакансию
   - Придерживаться одного формата


№9
Вот чек-лист для заполнения резюме Data Scientist на основе данного документа:

1. Контакты
   - Имя, фамилия
   - Город, страна
   - Email, телефон
   - LinkedIn

2. Цель
   - Желаемая должность и специализация

3. Краткое резюме
   - Опыт и навыки
   - Подход для вакансии

4. Навыки
   - Языки программирования
   - Фреймворки, библиотеки
   - Инструменты, технологии

5. Опыт работы
   - Названия компаний и проектов
   - Периоды работы
   - Должности
   - Ключевые результаты
   - Использованные технологии

6. Образование
   - Университеты, курсы
   - Специальности

7. Дополнительно
   - Проекты
   - Статьи, доклады
   - Участие в сообществе

8. Адаптация
   - Под вакансию и компанию
   - Ключевые слова
   - Подчеркивание опыта

9. Проверка
   - Грамматика
   - Актуальность контактов
   - Достоверность

10. Оформление
    - 1 страница
    - Структурированность
    - Выделение блоков


№10

Вот чек-лист по заполнению резюме на основе предоставленного текста:

1. Персональная информация
   - ФИО
   - Возраст
   - Контакты (телефон, email)
   - Фотография (опционально)

2. Образование
   - Названия учебных заведений
   - Специальности
   - Пройденные курсы

3. Опыт работы
   - Названия компаний
   - Периоды работы
   - Должности
   - Обязанности и достижения
   - Проекты

4. Навыки
   - Языки программирования
   - Технологии и инструменты
   - Уровни владения

5. Личные качества
   - Описание с примерами
   - Хобби и увлечения

6. Рекомендации
   - Контакты рекомендателей

7. Дополнительно
   - Цель
   - Видеорезюме
   - Проверка ошибок
   - Форматирование

7. Форматирование
   - Разбить текст на блоки
   - Использовать подзаголовки и списки
   - 1-2 страницы в объеме
   - 2 цвета, не много шрифтов
   - Выделять ключевые навыки

8. Сопроводительное письмо
   - Представление
   - Упоминание вакансии
   - Краткое описание опыта
   - Причина, почему подходите на вакансию

№10
Вот чек-лист для заполнения резюме на основе документа 10 резюме_.docx:

1. Контакты
   - ФИО
   - Город, страна
   - Телефон, email
   - LinkedIn

2. Фото
   - Деловой стиль
   - Хорошее качество
   - Небольшого размера

3. Цель
   - Желаемая должность и уровень

4. Краткое резюме
   - Опыт и навыки
   - Цели и планы

5. Образование
   - Учебные заведения
   - Специальности
   - Курсы и тренинги

6. Опыт работы
   - Названия компаний
   - Периоды работы
   - Должности
   - Обязанности, достижения
   - Технологии, навыки

7. Навыки
   - Языки программирования
   - Инструменты
   - Мягкие навыки

8. Языки
   - Английский
   - Другие языки
   - Уровни владения

9. О себе
   - Личные качества
   - Хобби, интересы

10. Проверка
    - Грамматика
    - Актуальность контактов
    - Форматирование

11. Оформление
    - 1-2 страницы
    - Структурированность
    - Выделение разделов


№11

Вот чек-лист по составлению резюме для IT-специалиста на основе данного документа:

1. Технологии
   - Перечислить технологии, инструменты и языки для каждого места работы
   - Указать требуемый для вакансии инструментарий

2. Примеры кода
   - Привести конкретные проекты
   - Добавить фрагменты кода (например, на GitHub)

3. Open Source
   - Отметить участие в проектах с открытым кодом

4. Краткость
   - Избегать длинных описаний в резюме
   - Подробности оставить для собеседования

5. Фотография
   - Добавить деловую фотографию
   - Не использовать личные, шуточные фото

6. Детали
   - Обратить внимание на важные детали для компании
   - Указать образование, если требуется

7. Грамотность
   - Проверить резюме на опечатки и ошибки
   - Грамотно сформулировать техническую информацию

8. Структура
   - Разбить на разделы (опыт, навыки, образование)
   - Выделить ключевые моменты

9. Оформление
   - Использовать подзаголовки, списки
   - 1-2 страницы в объеме


№12
Вот чек-лист по составлению IT резюме на основе данного документа:

1. Фото
   - Деловой стиль
   - Хорошее качество
   - Актуальное
   - Без лишних деталей на заднем фоне

2. Краткое резюме
   - Профессия и опыт
   - Основные обязанности и достижения
   - Цель и планы

3. Контакты
   - Имя и фамилия
   - Должность
   - Город и страна
   - Телефон и email
   - LinkedIn

4. Опыт работы
   - Название компаний
   - Периоды работы
   - Должности
   - Обязанности и достижения

5. Образование
   - Степени и специальности
   - Названия учебных заведений
   - Годы обучения
   - Курсы и тренинги

6. Языки
   - Английский
   - Другие языки
   - Уровни владения

7. Навыки
   - Технические навыки
   - Мягкие навыки

8. Хобби и интересы
   - Связанные с работой

9. Проверка и оформление
   - Проверка ошибок
   - Единый стиль
   - 1-2 страницы

№13
Вот чек-лист по составлению резюме на основе данного документа:

1. Выписать все навыки и опыт
   - Технологии, языки, фреймворки
   - Курсы, сертификаты, образование
   - Достижения, увлечения
   - Все, что может пригодиться

2. Определить ключевые достижения
   - Решенные проблемы
   - Улучшения и оптимизации
   - Нововведения
   - Количественные показатели результатов

3. Подобрать компании для отправки
   - Определить профиль компаний
   - Отфильтровать навыки под них
   - Создать персонализированные варианты резюме

4. Выделить важное в дизайне
   - Подчеркнуть ключевые навыки и достижения
   - Минимум шрифтов и цветов
   - Лаконичность и структурированность

5. Избегать лишнего в резюме
   - Не указывать неподтвержденные навыки
   - Не описывать подробно обязанности
   - Не упоминать личные качества и цели

6. Добавить сопроводительное письмо
   - Без грамматических ошибок
   - Упоминание вакансии и мотивации
   - Акцент на полезном опыте

7. Проверить на ошибки
   - Тщательно вычитать
   - Дать проверить другому человеку


№14

Вот чек-лист для составления IT резюме на основе данного документа:

1. Опыт работы
   - Указать только релевантный опыт в IT сфере
   - Детально описать последнее место работы
   - Не включать непрофильный опыт

2. Портфолио
   - Добавить ссылки на выполненные проекты
   - Описать свою роль и задачи в проектах

3. Технологический стек
   - Перечислить используемые технологии
   - Указать уровень владения ими

4. Образование
   - Добавить, если есть профильное образование
   - Можно опустить, если обучались на курсах

5. Контакты
   - Указать актуальные контакты для связи
   - Добавить мессенджеры и социальные сети

6. Сопроводительное письмо
   - Кратко описать опыт и достижения
   - Объем 500-1000 символов

7. Проверка
   - Исправить грамматические ошибки
   - Дать проверить другому человеку

8. Оформление
   - Структурировать и выделить разделы
   - Использовать списки и подзаголовки

№15
Вот чек-лист для составления IT резюме на основе данного документа:

1. Название
   - Имя и должность

2. Формат
   - DOC или PDF

3. Фото
   - Деловой стиль (необязательно)
   - Небольшого размера

4. Контакты
   - Телефон, email, скайп, город
   - Без личной информации
   - Проверить корректность

5. Цель
   - Желаемая должность

6. Краткое резюме
   - Опыт и навыки
   - Достижения

7. Образование
   - Профильное
   - Курсы и тренинги

8. Опыт работы
   - Только в IT сфере
   - Подробно о последнем месте

9. Языки
   - Уровень по международной шкале
   - Английский обязателен

10. Навыки
    - Технологии и инструменты
    - Мягкие навыки

11. Дополнительно
    - Хобби, личные качества
    - Релокация, визы

12. Портфолио и GitHub
    - Ссылки на проекты

13. Проверка и отправка
    - Проверить ошибки
    - Отправлять на подходящие вакансии

№16
Вот чек-лист для заполнения резюме на основе данного документа:

1. Контакты
   - Имя
   - Email
   - Телефон

2. Цель
   - Краткое резюме поиска работы

3. Навыки
   - 5-10 ключевых навыков
   - Без версий и лет опыта

4. Опыт работы
   - Название компании
   - Период работы
   - Должность
   - 3 ключевых результата

5. Образование
   - Учебные заведения
   - Специальности

6. Дополнительно
   - Конференции и митапы
   - Статьи и выступления
   - Проекты и репозитории

7. Рекомендации
   - Контакты для рекомендаций

8. Сопроводительное письмо
   - Приветствие
   - Подход для вакансии
   - Контакты для связи

9. Проверка
   - Грамматика и орфография
   - Ключевые слова
   - Выделение из общего фона

10. Объем и оформление
    - 1-2 страницы
    - Структурированность

№17
Вот чек-лист для заполнения IT резюме на основе предоставленного документа:

1. Контакты
   - ФИО
   - Телефон, email
   - Мессенджеры, соцсети
   - Город, страна

2. Краткое резюме
   - Опыт и навыки
   - Подход для вакансии

3. Опыт работы
   - Название компании и проекта
   - Период работы
   - Должность
   - Обязанности
   - Достижения
   - Технологии
   - Навыки
   - Рекомендации

4. Образование
   - ВУЗы, курсы
   - Специальности

5. Навыки
   - Языки, технологии
   - Мягкие навыки

6. Дополнительно
   - Языки, готовность к командировкам
   - Хобби, личные качества

7. Проверка
   - Правдивость
   - Релевантность
   - Краткость
   - Ошибки

8. Оформление
   - Структурированность
   - Выделение разделов
   - 1-2 страницы
"""

# %% [markdown]
# ### Шаблоны

# %%
chunks = text.split('\n\n')
len(chunks)
# Out:
# 244

# %%
titles = [chunk.split('\n')[0] for chunk in chunks]
len(titles)
# Out:
# 244

# %%
titles = [''.join([s for s in title if (s.isalpha() or s==" ")]).strip() for title in titles]

# %%
set(titles)

# %%
[chunk for chunk in chunks if "бразование" in chunk.split('\n')[0]]
# Out:
# ['5. Образование:\n   - Учебные заведения\n   - Специальности\n   - Даты обучения\n   - Курсы, тренинги, сертификаты\n   - Пример',
#  '5. Образование:\n- Указаны даты, вуз, специальность, степень, средний балл',
#  '3. Образование:  \n- Указаны учебные заведения, специальности, даты обучения',
#  '4. Образование\n   - Учебные заведения\n   - Степени\n   - Даты окончания',
#  '4. Образование:  \n- Перечислить с указанием дат обучения\n- Не указывать среднее образование',
#  '3. Образование\n   - Учебные заведения\n   - Специальности\n   - Даты окончания\n   - Курсы и сертификаты',
#  '5. Образование\n   - ВУЗы и факультеты\n   - Профильные курсы',
#  'Образование:\n- Указать учебные заведения, специальности, годы учебы',
#  'Образование:\n- Перечислить учебные заведения в обратном порядке  \n- Указать специальности, степени, годы обучения\n- Добавить полученные награды и стипендии',
# ...

# %% [markdown]
# ## Замечания по резюме

# %%
comments = """\
# Фатеева
- Гигантская фотография в резюме, несоответствующая размеру остальной информации.
- Неопределенное название раздела "Опыт", должно быть "Профессиональная деятельность".
- Отсутствие информации о контактах сверху резюме.
- Информация о языках представлена в виде картинок флагов стран, что неудобно для чтения и лучше было бы указать язык и уровень навыка в словесной форме.
- Блок "Дополнительные навыки" содержит перечисление общих качеств, которые не отличают данного соискателя от других.
- Блок навыков должен содержать конкретные навыки и технологии, которыми соискатель владеет.
- Образование указано снизу резюме, хотя должно быть расположено выше блока "Профессиональная деятельность".
- В информации об образовании не указан конкретный университет, только факультет.
- Раздел "Опыт" содержит только общее описание должностей, без конкретных задач и достижений.
- Отсутствие блока с информацией о соискателе самом, такой как краткая самооценка или профессиональные цели.
- Фотография соискателя должна быть уменьшена до соответствующего размера.
- Нужно более ясное разделение информации на задачи, достижения, стек и ссылку на проекты для каждой позиции в опыте работы.
- Исправить опечатку в слове "бакалавриад".
- Убрать блок "Дополнительные навыки" или заменить его на конкретные навыки и технологии, которыми соискатель владеет.

Вот список замечаний HR-специалиста к резюме Фатиевой Кристины:
1. Огромная фотография на половину страницы. Нужно уменьшить.
2. Блок "Опыт" некорректно оформлен. Должна быть "Профессиональная деятельность".
3. Неправильная последовательность разделов. Должно быть: контакты, информация о себе, навыки, профессиональная деятельность, образование.
4. Контакты указаны внизу вместо верха.
5. В разделе языки вместо уровня владения нарисованы флажки. Нужно конкретно прописать уровень.
6. Раздел "Дополнительные навыки" лишний. Его нужно убрать.
7. В блоке "Профессиональная деятельность" должны быть выделены отдельно должности, название компаний и разбито на задачи и достижения.
8. Нет информации об образовании в области ИТ/данных, непонятно зачем подавать резюме на ИТ-вакансии.
9. В разделе "Образование" информация представлена некорректно, должно быть: название учебного заведения, факультет, специальность/степень.
10. Нужно полностью переделать раздел "Профессиональная деятельность" - выделить задачи и достижения.
11. В разделе "Образование" также исправить последовательность и разбить на отдельные строки.


# Рогожин
1. Резюме растянуто на две страницы, нужно уместить все информацию на одной странице.
2. Резюме содержит сплошной текст, все должно быть разделено по строчкам.
3. Первое имя "Рогожин Михаил Валерьевич" выделено жирным шрифтом, это нужно исправить - все должно быть одним шрифтом.
4. Контактная информация (телефон, email) должна быть выделена отдельным блоком.
5. В блоке образования необходимо внести все данные по образованию построчно, а не сплошным текстом.
6. Навыки должны быть прописаны четко в резюме, а не предоставлены в виде ссылки на таблицу.
7. Блоки "Опыт разработки", "В стартапе по анализу исходного кода смарт-контракта (BSC)" и "Имею опыт проектирования информационных систем" содержат сплошной текст и необходимо разделить информацию по строчкам.
8. Блок "Опыт разработки" должен быть разделен на стажировки и работу, с указанием названия стажировки/организации, задач и достижений, а также использованного стека.
9. Нет информации о блоке "О себе", название и содержание этого блока должны быть добавлены.
10. Согласованность форматирования текста, например, указание года работ/стажировок (2020 год. Второе высшее образование, 2021 год. Прошел обучение и т.д.).
11. Необходимо проверить и исправить грамматические и орфографические ошибки в тексте резюме.
12. Удаление ссылки на Google таблицу навыков и замена ее на перечисление навыков в тексте резюме.
13. Уточнение информации о самообразовании и опыте работы, чтобы было понятно, какие задачи выполнялись и какие навыки были получены.
14. Определение формата предоставляемой информации, чтобы было понятно, где указывается период работы, описание задач, достижения и использованный стек.
15. Использование языка официальных документов и профессиональных терминов.

Вот список замечаний HR-специалиста к резюме Рогожина Михаила Валерьевича:

1. Резюме растянуто на две страницы, должно быть компактнее, уместиться на одной
2. Весь текст сплошной, нужно разделять по строкам и абзацам
3. Нельзя оставлять пустые полустраницы
4. Все должно быть написано одним шрифтом, без выделения фамилии
5. Блок "Контакты" лучше выделить, но не обязательно
6. Телефон должен быть без пробелов и скобок
7. Нет telegram
8. Таблица навыков неприемлема, навыки должны быть прописаны в резюме
9. Блоки перепутаны местами, сначала должен быть опыт работы, потом образование и навыки
10. Образование не структурировано, нужно по годам и организациям
11. В опыте работы сплошной текст, нужно разбить на стажировки и работу
12. Для каждого места работы указать период, задачи, достижения, стэк
13. Нет блока "О себе"
14. Всю информацию нужно переделывать и структурировать


# Макеев
1. Дублирование ФИО в блоке "Профиль".
2. Ненужные данные, такие как дата рождения и адрес, должны быть удалены.
3. Необходимо объединить блоки "Контакты" и "Профиль" в один блок "Контакты".
4. Не указана информация о себе в самом начале резюме.
5. Нет ссылки на профиль на GitHub.
6. Контактные данные размазаны по всему резюме, они должны быть сконцентрированы в одном блоке сверху.
7. В блоке "Опыт работы" не указаны названия организаций, задачи и достижения.
8. Дублирование информации об образовании, нужно оставить только одну упоминание каждого университета.
9. Не указаны степени и специальности, полученные в университетах.
10. В любом резюме все кавычки должны быть елочками.
11. Блок "Навыки" не содержит навыков вообще.
13. Недостаточно информации в резюме.

Вот список замечаний и ошибок в резюме, указанных HR-специалистом:

1. ФИО соискателя указано два раза - в блоке "Профиль" и сверху резюме. Должно быть только один раз.
2. В блоке "Профиль" не нужна дата рождения.
3. В блоке "Профиль" не нужен адрес.
4. Блок "Профиль" назван неправильно, должен называться "Контакты".
5. Блоки "Профиль" и "Связь" нужно объединить, оставив только телефон, email и телеграм.
6. Нет блока "О себе" в самом начале резюме.
7. Нет ссылки на GitHub.
8. Контакты размазаны по всему резюме, а должны быть сверху.
9. В блоке "Опыт работы" указаны только должности и период, но не указаны названия организаций, задачи, достижения.
10. В блоке "Образование" неправильно указан 2023 год.
11. В блоке "Образование" не хватает информации об университетах - степень, специальность.
12. По всему резюме должны использоваться кавычки-елочки.
13. Блок "Навыки" написан в самом низу, а должен быть наверху.
14. В блоке "Навыки" на самом деле нет информации о навыках.
15. В целом в резюме мало информации.
16. Контактная информация должна находиться в блоке "Контакты", а не разбросана по разным разделам таким, как "Профиль", "Связь" и аналогичные.


# Казюлин
1. Необходимо добавить ФИО кандидата Сергея Казюлина.
2. Адрес электронной почты и номер телефона должны быть расположены сверху резюме, а не на боковой панели.
3. Желаемый уровень зарплаты не должен быть указан в резюме.
4. Список навыков должен быть оформлен в виде простого перечисления, а не разбит на два столбика.
5. Блок образования и опыта работы должен быть отдельными разделами.
6. Для обучения университету искусственного интеллекта необходимо указать, каким образом кандидат участвовал в обучении и какие задачи были выполнены.
7. В блоке опыта работы необходимо расписать задачи, достижения и ответственности, а также указать продолжительность работы.
8. Блок "О себе" должен быть помещен в начало резюме и состоять из 2-3 предложений о ключевых навыках и интересах кандидата.
9. Блок "Изученная литература" не является необходимым и должен быть удален из резюме.
10. Резюме должно быть компактным и помещаться на одну страницу. Необходимо удалить избыточную информацию и сократить объем текста.


Вот список замечаний и ошибок в резюме Казюлина Сергея, указанных HR-специалистом:

1. Слишком много свободного пространства над блоком с ФИО.
2. Не нужно указывать отчество в ФИО.
3. Не указан Telegram, что является важным в настоящее время.
4. Контактная информация (телефон, email) расположена неудачно, лучше справа.
5. Не нужны блоки "Желаемый формат работы" и "Желаемый уровень ЗП". Это ограничивает кандидата.
6. Блок "AI навыки" занимает слишком много места, должен быть переработан в простой список технологий и языков.
7. Неправильная последовательность блоков. Должно быть: контакты, о себе, навыки, образование, опыт работы.
8. В блоке "Обучение" не расписано, чему и где конкретно обучался соискатель.
9. Блок "Опыт и проекты" должен называться "Опыт работы".
10. В блоке опыта работы нет информации о должностных обязанностях и достижениях.
11. Указана информация о работе старше 10 лет, что нежелательно.
12. Блок "О себе" содержит слишком много текста. Должен быть 2-3 предложения.
13. Блок "Изученная литература" не нужен в резюме.
14. Резюме должно умещаться на 1 странице, сейчас оно занимает 2.
15. Много разрывов и переносов слов, плохая читабельность.


# Кобызев

1. Резюме слишком длинное и должно быть умещено на одну страницу.
2. Необходимо разделить информацию о каждой позиции на отдельные строки: организация, должность, задачи и достижения.
3. Отсутствуют достижения в опыте работы и должностные обязанности были неправильно описаны.
4. Непонятно, к какой должности относится информация о "операторе спортивной связи" и "начальнике дела".
5. Не указаны годы работы в определенных проектах, а также отсутствуют достижения и задачи для них.
6. Приведенные проекты и стажировки не разделены по отдельным категориям и смешаны в одном разделе.
7. Некорректно написаны даты, например "9-НВР", и форматы дат различаются в разных разделах.
8. Расположение информации об образовании и программе обучения в университете искусственного интеллекта не соответствует правилам.
9. Необходимо указать тренинги и сертификаты в отдельном разделе.
10. Учебные разделы должны быть указаны только в разделе образования.

Вот полный список замечаний и ошибок в резюме, указанных HR-специалистом:
1. Резюме слишком длинное, необходимо уместить всю информацию на 1 страницу.
2. В блоке "Профессиональные навыки" непонятно, зачем указана первая строка "Разработка архитектуры и организация внедрения систем ИИ в производство". Её нужно убрать.
3. В блоке "Опыт работы" информация должна быть структурирована - сначала организация, затем должность, потом обязанности. Сейчас всё написано вперемешку.
4. Также в этом блоке отсутствует указание на достижения на каждом месте работы.
5. Блок "Проекты в области ИИ" на самом деле содержит смесь проектов, стажировок и учебы. Это нужно четко разграничить.
6. Даты в резюме указаны безграмотно и не по одному формату - "9-НВР" и т.д. Даты должны быть в одном формате - месяц и год.
7. Блок с образованием расположен в резюме неправильно - оно должно идти строго в хронологическом порядке: сначала последнее образование, затем предыдущее.
8. Ссылки на дипломы и сертификаты лишние, необходимо описывать достижения и курсы в резюме, а не давать ссылки.
9. Сертификаты должны быть выделены в отдельный блок, а не объединены с тренингами.
10. Учёба в Университете ИИ должна быть указана только 1 раз в блоке "Образование".
"""

# %%
chnks = comments.split('\n')

# %%
educations = [chnk.strip() for chnk in chnks if "бразован" in chnk]

# %%
educations
# Out:
# ['- Образование указано снизу резюме, хотя должно быть расположено выше блока "Профессиональная деятельность".',
#  '- В информации об образовании не указан конкретный университет, только факультет.',
#  '3. Неправильная последовательность разделов. Должно быть: контакты, информация о себе, навыки, профессиональная деятельность, образование.',
#  '8. Нет информации об образовании в области ИТ/данных, непонятно зачем подавать резюме на ИТ-вакансии.',
#  '9. В разделе "Образование" информация представлена некорректно, должно быть: название учебного заведения, факультет, специальность/степень.',
#  '11. В разделе "Образование" также исправить последовательность и разбить на отдельные строки.',
#  '5. В блоке образования необходимо внести все данные по образованию построчно, а не сплошным текстом.',
#  '10. Согласованность форматирования текста, например, указание года работ/стажировок (2020 год. Второе высшее образование, 2021 год. Прошел обучение и т.д.).',
# ...
